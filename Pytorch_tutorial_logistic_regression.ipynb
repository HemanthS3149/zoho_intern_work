# %% [markdown]
# <a href="https://colab.research.google.com/github/HemanthS3149/zoho_intern_work/blob/Week-4/Pytorch_tutorial_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Working with Images & Logistic Regression in PyTorch**

# %% [markdown]
# Using PyTorch and logistic regression for image classification (MNIST Dataset)

# %% [markdown]
# Torchvision is a package in PyTorch ecosystem, designed primarily for CV tasks.It provides tools that facilitate manipulation,processing,handling of image data, which are commonly used in DL models for vision applications.

# %%
import torch
import torchvision
from torchvision.datasets import MNIST

# %%
#Downloading training dataset
dataset=MNIST(root='data/',download=True)

# %%
len(dataset)

# %% [markdown]
# There are 60000 images to train the model with.

# %%
test_dataset=MNIST(root='data/',train=False) #To retrive test data
len(test_dataset)

# %%
dataset[0] #Image size is 28x28
#Class of image is PIL.Image.Image

# %%
import matplotlib.pyplot as plt
image,label=dataset[0]
plt.imshow(image,cmap='gray')
print("Label:",label)

# %%
image,label=dataset[90]
plt.imshow(image,cmap='gray')
print("Label:",label)

# %% [markdown]
# Pytorch does not know to work with images, but can work well with tensors. To solve this problem, we can specify a transform while creating our dataset

# %% [markdown]
# We shall use the ToTensor transform to convert images into PyTorch tensors

# %%
import torchvision.transforms as transforms

# %%
#MNIST dataset(images and labels)
dataset=MNIST(root='data/',train=True,transform=transforms.ToTensor())

# %%
img_tensor,label=dataset[10]
print(img_tensor.shape,label)

# %% [markdown]
# This image is converted to a 1x28x28 tensor. 1st dimension tracks the color channels.

# %%
print(img_tensor[0,10:15,10:15])#0th image tensor la, 10-15 rows and columns

# %%
plt.imshow(img_tensor[0,10:15,10:15],cmap='gray')

# %%
from torch.utils.data import random_split
train_ds,val_ds=random_split(dataset,[50000,10000]) #We take the val_ds from the training dataset
len(train_ds),len(val_ds)

# %%
from torch.utils.data import DataLoader #Dataloader is used for batching and parallesim purposes
batch_size=128
train_loader=DataLoader(train_ds,batch_size,shuffle=True)#To ensure that batches generated in each epoch are different
val_loader=DataLoader(val_ds,batch_size)#Since val_ds is used only for evaluating the model, no need to shuffle images

# %% [markdown]
# We now use nn.Linear to create the LR model.Since nn.Linear expects the training example to be a vector, each 1x28x28 image tensor is flattened into vector of size 784(28x28)

# %% [markdown]
# The output for each image is a vector of size 10,with each element telling prob of 0 to 9

# %%
import torch.nn as nn
input_size=28*28
num_classes=10
#Logistic regression model
model=nn.Linear(input_size,num_classes)

# %%
print(model.weight.shape)
print(model.weight)

# %%
print(model.bias.shape)
model.bias

# %% [markdown]
# There are 7850 parameters here. Now, try to generate some outputs for our model. Taking first batch of 100 images from dataset and passing into the model

# %%
for images,labels in train_loader:
  print(labels)
  print(images.shape)
  outputs=model(images)
  print(outputs)
  break

# %%
images.shape

# %%
images.reshape(128,784).shape #from 128,1,28,28 we made it to 128,784 for the nn.layer to accept

# %% [markdown]
# Extending the nn.Module class from Pytorch to define a custom model

# %%
class MnistModel(nn.Module):
  def __init__(self): #inside the __init__ method, we instantiate the weights and biases using nn.Linear()
    super().__init__() #calls the constructor of the base class to properly initialize the model
    self.linear=nn.Linear(input_size,num_classes)#defines a linear layer, which automatically initializes the weights and biases for the linear transformation

  def forward(self,xb):#We flatten the input tensor and pass it onto self.linear. It takes an input tensor xb and processes it through the model
    xb=xb.reshape(-1,784) #-1 refers to the batch_size
    out=self.linear(xb) #passes the flattened input through the linear layer,producing an output tensor
    return out
model=MnistModel()#defines a simple nn with a single linear layer, suitable for a basic Logistic regression classifier

# %%
model.linear

# %%
print(model.linear.weight.shape, model.linear.bias.shape)
list(model.parameters())

# %% [markdown]
# We can use our new custom model in the same way as before.

# %%
for images,labels in train_loader:
  print(images.shape)
  outputs=model(images)
  break

print("Outputs.shape:",outputs.shape)
print("Sample outputs:\n",outputs[:3].data)

# %% [markdown]
# To convert the output rows into probabilities, we use the softmax function

# %%
import torch.nn.functional as F

# %%
outputs[0:2].data

# %%
#Apply softmax for each output row
probs=F.softmax(outputs,dim=1)
print("Sample probablities:\n",probs[:2].data)
print("Sum: ",torch.sum(probs[0]).item())

# %%
max_probs,preds=torch.max(probs,dim=1)
print(preds)
print(max_probs)

# %% [markdown]
# We will not get accurate results cause we randomly initialized weights and biases. We need to train the model, i.e adjust the weights using gradient descent to make better predictions

# %%
labels

# %%
outputs[0:2]

# %%
torch.sum(preds==labels)

# %%
def accuracy(outputs,labels):
  _,preds=torch.max(outputs,dim=1) #first tensor has maximum values along dim=1 and 2nd tensor has indices of the maximum values(which represent predicted classes)
  return torch.tensor(torch.sum(preds==labels).item()/len(preds))#_ indicates we are not interested in storing or using the first tensor(containing the max values)

# %%
accuracy(outputs,labels)

# %% [markdown]
# We use cross-entropy as a loss function for classification problems

# %%
loss_fn=F.cross_entropy

# %%
#Loss for current batch of data
loss=loss_fn(outputs,labels)
print(loss)

# %% [markdown]
# Cross entropy is the -ve log of the predicted prob of the correct label averaged over all training examples

# %% [markdown]
# Model Training

# %% [markdown]
# for epoch in range(num_epochs):
#  #Training phase
# * for batch in train_loader
# *   Generate preds
#
# *   Calculate loss
# *   Compute gradients
#
#
# *   Update weights
#
# *   Reset Gradients
#
#   #Validation Phase
#
#
# for batch in val_loader:
# *   Generate preds
# *   Calculate loss
# *   Calculate metrics(accuracy...)

# %%
class MnistModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear=nn.Linear(input_size,num_classes)#Single layer for imp logistic regression

  def forward(self,xb):
    xb=xb.reshape(-1,784)
    out=self.linear(xb)
    return out

  def training_step(self,batch):
    images,labels=batch
    out=self(images)
    loss=F.cross_entropy(out,labels)
    return loss

  def validation_step(self,batch):
    images,labels=batch
    out=self(images)
    loss=F.cross_entropy(out,labels)
    acc=accuracy(out,labels)
    return {'val_loss':loss,'val_acc':acc}

  def validation_epoch_end(self,outputs):
    batch_losses=[x['val_loss'] for x in outputs]
    epoch_loss=torch.stack(batch_losses).mean() #mean of all losses
    batch_accs=[x['val_acc'] for x in outputs]
    epoch_acc=torch.stack(batch_accs).mean() #mean of all accuracies
    return {'val_loss':epoch_loss.item(),'val_acc':epoch_acc.item()}

  def epoch_end(self, epoch, result):
        print("Epoch [{}], val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['val_loss'], result['val_acc']))

model=MnistModel()

# %% [markdown]
# Now defining an evaluate function, which performs validation phase and a fit func which will perform the entire training process

# %%
def evaluate(model,val_loader):
  outputs=[model.validation_step(batch) for batch in val_loader]
  return model.validation_epoch_end(outputs)

def fit(epochs,lr,model,train_loader,val_loader,opt_fun=torch.optim.SGD):
  history=[]
  optimizer=opt_fun(model.parameters(),lr) #we pass on w and b and learning rate to the opt_fun
  for epoch in range(epochs):
    #Training phase
    for batch in train_loader:
      loss=model.training_step(batch)
      loss.backward() #compulsory in all cases
      optimizer.step()
      optimizer.zero_grad() #resets the gradients to 0
     #Validation phase
    result=evaluate(model,val_loader)
    model.epoch_end(epoch,result)
    history.append(result)
  return history

# %%
result0=evaluate(model,val_loader)
result0

# %%
history1=fit(5,0.001,model,train_loader,val_loader)
# Out:
# Epoch[0],val_loss:2.3191,val_acc:0.1301
# Epoch[0],val_loss:2.3180,val_acc:0.1307
# Epoch[0],val_loss:2.3167,val_acc:0.1319
# Epoch[0],val_loss:2.3157,val_acc:0.1330
# Epoch[0],val_loss:2.3147,val_acc:0.1342
# Epoch[0],val_loss:2.3135,val_acc:0.1340
# Epoch[0],val_loss:2.3125,val_acc:0.1357
# Epoch[0],val_loss:2.3114,val_acc:0.1378
# Epoch[0],val_loss:2.3101,val_acc:0.1397
# Epoch[0],val_loss:2.3089,val_acc:0.1405
# Epoch[0],val_loss:2.3079,val_acc:0.1417
# Epoch[0],val_loss:2.3068,val_acc:0.1424
# Epoch[0],val_loss:2.3058,val_acc:0.1433
# Epoch[0],val_loss:2.3046,val_acc:0.1446
# Epoch[0],val_loss:2.3035,val_acc:0.1455
# Epoch[0],val_loss:2.3025,val_acc:0.1469
# Epoch[0],val_loss:2.3015,val_acc:0.1479
# Epoch[0],val_loss:2.3004,val_acc:0.1495
# Epoch[0],val_loss:2.2993,val_acc:0.1499
# Epoch[0],val_loss:2.2981,val_acc:0.1510
# Epoch[0],val_loss:2.2968,val_acc:0.1513
# Epoch[0],val_loss:2.2955,val_acc:0.1525
# Epoch[0],val_loss:2.2943,val_acc:0.1535
# Epoch[0],val_loss:2.2932,val_acc:0.1546
# Epoch[0],val_loss:2.2922,val_acc:0.1558
# Epoch[0],val_loss:2.2909,val_acc:0.1564
# Epoch[0],val_loss:2.2898,val_acc:0.1573
# Epoch[0],val_loss:2.2889,val_acc:0.1592
# Epoch[0],val_loss:2.2876,val_acc:0.1605
# Epoch[0],val_loss:2.2866,val_acc:0.1611
# Epoch[0],val_loss:2.2853,val_acc:0.1620
# Epoch[0],val_loss:2.2843,val_acc:0.1631
# Epoch[0],val_loss:2.2831,val_acc:0.1642
# Epoch[0],val_loss:2.2821,val_acc:0.1647
# Epoch[0],val_loss:2.2810,val_acc:0.1657
# Epoch[0],val_loss:2.2797,val_acc:0.1666
# Epoch[0],val_loss:2.2786,val_acc:0.1673
# Epoch[0],val_loss:2.2776,val_acc:0.1691
# Epoch[0],val_loss:2.2765,val_acc:0.1699
# Epoch[0],val_loss:2.2753,val_acc:0.1711
# Epoch[0],val_loss:2.2742,val_acc:0.1718
# Epoch[0],val_loss:2.2731,val_acc:0.1738
# Epoch[0],val_loss:2.2720,val_acc:0.1756
# Epoch[0],val_loss:2.2708,val_acc:0.1784
# Epoch[0],val_loss:2.2697,val_acc:0.1794
# Epoch[0],val_loss:2.2686,val_acc:0.1798
# Epoch[0],val_loss:2.2676,val_acc:0.1808
# Epoch[0],val_loss:2.2666,val_acc:0.1815
# Epoch[0],val_loss:2.2656,val_acc:0.1825
# Epoch[0],val_loss:2.2643,val_acc:0.1859
# Epoch[0],val_loss:2.2631,val_acc:0.1872
# Epoch[0],val_loss:2.2621,val_acc:0.1889
# Epoch[0],val_loss:2.2610,val_acc:0.1907
# Epoch[0],val_loss:2.2599,val_acc:0.1922
# Epoch[0],val_loss:2.2588,val_acc:0.1934
# Epoch[0],val_loss:2.2577,val_acc:0.1954
# Epoch[0],val_loss:2.2568,val_acc:0.1960
# Epoch[0],val_loss:2.2559,val_acc:0.1975
# Epoch[0],val_loss:2.2548,val_acc:0.1983
# Epoch[0],val_loss:2.2537,val_acc:0.2001
# Epoch[0],val_loss:2.2527,val_acc:0.2009
# Epoch[0],val_loss:2.2516,val_acc:0.2020
# Epoch[0],val_loss:2.2504,val_acc:0.2036
# Epoch[0],val_loss:2.2492,val_acc:0.2040
# Epoch[0],val_loss:2.2482,val_acc:0.2055
# Epoch[0],val_loss:2.2471,val_acc:0.2069
# Epoch[0],val_loss:2.2461,val_acc:0.2082
# Epoch[0],val_loss:2.2451,val_acc:0.2096
# Epoch[0],val_loss:2.2441,val_acc:0.2119
# Epoch[0],val_loss:2.2431,val_acc:0.2124
# Epoch[0],val_loss:2.2420,val_acc:0.2147
# Epoch[0],val_loss:2.2409,val_acc:0.2163
# Epoch[0],val_loss:2.2398,val_acc:0.2166
# Epoch[0],val_loss:2.2388,val_acc:0.2185
# Epoch[0],val_loss:2.2377,val_acc:0.2202
# Epoch[0],val_loss:2.2365,val_acc:0.2228
# Epoch[0],val_loss:2.2354,val_acc:0.2236
# Epoch[0],val_loss:2.2345,val_acc:0.2258
# Epoch[0],val_loss:2.2334,val_acc:0.2277
# Epoch[0],val_loss:2.2324,val_acc:0.2283
# Epoch[0],val_loss:2.2314,val_acc:0.2291
# Epoch[0],val_loss:2.2302,val_acc:0.2304
# Epoch[0],val_loss:2.2291,val_acc:0.2325
# Epoch[0],val_loss:2.2281,val_acc:0.2336
# Epoch[0],val_loss:2.2270,val_acc:0.2354
# Epoch[0],val_loss:2.2260,val_acc:0.2372
# Epoch[0],val_loss:2.2249,val_acc:0.2387
# Epoch[0],val_loss:2.2240,val_acc:0.2396
# Epoch[0],val_loss:2.2229,val_acc:0.2404
# Epoch[0],val_loss:2.2219,val_acc:0.2417
# Epoch[0],val_loss:2.2208,val_acc:0.2427
# Epoch[0],val_loss:2.2198,val_acc:0.2446
# Epoch[0],val_loss:2.2187,val_acc:0.2470
# Epoch[0],val_loss:2.2176,val_acc:0.2479
# Epoch[0],val_loss:2.2166,val_acc:0.2496
# Epoch[0],val_loss:2.2155,val_acc:0.2527
# Epoch[0],val_loss:2.2143,val_acc:0.2552
# Epoch[0],val_loss:2.2134,val_acc:0.2547
# Epoch[0],val_loss:2.2123,val_acc:0.2569
# Epoch[0],val_loss:2.2110,val_acc:0.2594
# Epoch[0],val_loss:2.2102,val_acc:0.2593
# Epoch[0],val_loss:2.2092,val_acc:0.2612
# Epoch[0],val_loss:2.2082,val_acc:0.2633
# Epoch[0],val_loss:2.2069,val_acc:0.2638
# Epoch[0],val_loss:2.2059,val_acc:0.2654
# Epoch[0],val_loss:2.2049,val_acc:0.2671
# Epoch[0],val_loss:2.2038,val_acc:0.2679
# Epoch[0],val_loss:2.2029,val_acc:0.2692
# Epoch[0],val_loss:2.2018,val_acc:0.2700
# Epoch[0],val_loss:2.2008,val_acc:0.2713
# Epoch[0],val_loss:2.1999,val_acc:0.2720
# Epoch[0],val_loss:2.1989,val_acc:0.2730
# Epoch[0],val_loss:2.1980,val_acc:0.2737
# Epoch[0],val_loss:2.1970,val_acc:0.2743
# Epoch[0],val_loss:2.1959,val_acc:0.2752
# Epoch[0],val_loss:2.1950,val_acc:0.2772
# Epoch[0],val_loss:2.1941,val_acc:0.2788
# Epoch[0],val_loss:2.1931,val_acc:0.2792
# Epoch[0],val_loss:2.1921,val_acc:0.2789
# Epoch[0],val_loss:2.1912,val_acc:0.2808
# Epoch[0],val_loss:2.1903,val_acc:0.2822
# Epoch[0],val_loss:2.1892,val_acc:0.2846
# Epoch[0],val_loss:2.1882,val_acc:0.2856
# Epoch[0],val_loss:2.1872,val_acc:0.2869
# Epoch[0],val_loss:2.1863,val_acc:0.2882
# Epoch[0],val_loss:2.1854,val_acc:0.2886
# Epoch[0],val_loss:2.1844,val_acc:0.2906
# Epoch[0],val_loss:2.1835,val_acc:0.2915
# Epoch[0],val_loss:2.1824,val_acc:0.2933
# Epoch[0],val_loss:2.1815,val_acc:0.2943
# Epoch[0],val_loss:2.1805,val_acc:0.2958
# Epoch[0],val_loss:2.1795,val_acc:0.2978
# Epoch[0],val_loss:2.1784,val_acc:0.2997
# Epoch[0],val_loss:2.1775,val_acc:0.3011
# Epoch[0],val_loss:2.1765,val_acc:0.3023
# Epoch[0],val_loss:2.1755,val_acc:0.3029
# Epoch[0],val_loss:2.1745,val_acc:0.3043
# Epoch[0],val_loss:2.1736,val_acc:0.3056
# Epoch[0],val_loss:2.1726,val_acc:0.3077
# Epoch[0],val_loss:2.1717,val_acc:0.3085
# Epoch[0],val_loss:2.1706,val_acc:0.3102
# Epoch[0],val_loss:2.1695,val_acc:0.3111
# Epoch[0],val_loss:2.1685,val_acc:0.3119
# Epoch[0],val_loss:2.1676,val_acc:0.3135
# Epoch[0],val_loss:2.1665,val_acc:0.3151
# Epoch[0],val_loss:2.1654,val_acc:0.3179
# Epoch[0],val_loss:2.1646,val_acc:0.3186
# Epoch[0],val_loss:2.1636,val_acc:0.3200
# Epoch[0],val_loss:2.1626,val_acc:0.3213
# Epoch[0],val_loss:2.1617,val_acc:0.3225
# Epoch[0],val_loss:2.1607,val_acc:0.3238
# Epoch[0],val_loss:2.1598,val_acc:0.3249
# Epoch[0],val_loss:2.1589,val_acc:0.3262
# Epoch[0],val_loss:2.1580,val_acc:0.3278
# Epoch[0],val_loss:2.1570,val_acc:0.3292
# Epoch[0],val_loss:2.1559,val_acc:0.3313
# Epoch[0],val_loss:2.1550,val_acc:0.3323
# Epoch[0],val_loss:2.1540,val_acc:0.3325
# Epoch[0],val_loss:2.1530,val_acc:0.3329
# Epoch[0],val_loss:2.1519,val_acc:0.3344
# Epoch[0],val_loss:2.1511,val_acc:0.3354
# Epoch[0],val_loss:2.1503,val_acc:0.3359
# Epoch[0],val_loss:2.1493,val_acc:0.3386
# Epoch[0],val_loss:2.1483,val_acc:0.3402
# Epoch[0],val_loss:2.1475,val_acc:0.3411
# Epoch[0],val_loss:2.1465,val_acc:0.3418
# Epoch[0],val_loss:2.1455,val_acc:0.3433
# Epoch[0],val_loss:2.1446,val_acc:0.3446
# Epoch[0],val_loss:2.1436,val_acc:0.3458
# Epoch[0],val_loss:2.1426,val_acc:0.3472
# Epoch[0],val_loss:2.1417,val_acc:0.3481
# Epoch[0],val_loss:2.1407,val_acc:0.3489
# Epoch[0],val_loss:2.1397,val_acc:0.3503
# Epoch[0],val_loss:2.1389,val_acc:0.3526
# Epoch[0],val_loss:2.1379,val_acc:0.3539
# Epoch[0],val_loss:2.1370,val_acc:0.3548
# Epoch[0],val_loss:2.1359,val_acc:0.3558
# Epoch[0],val_loss:2.1350,val_acc:0.3573
# Epoch[0],val_loss:2.1341,val_acc:0.3587
# Epoch[0],val_loss:2.1331,val_acc:0.3601
# Epoch[0],val_loss:2.1320,val_acc:0.3622
# Epoch[0],val_loss:2.1310,val_acc:0.3646
# Epoch[0],val_loss:2.1302,val_acc:0.3661
# Epoch[0],val_loss:2.1293,val_acc:0.3678
# Epoch[0],val_loss:2.1284,val_acc:0.3690
# Epoch[0],val_loss:2.1276,val_acc:0.3703
# Epoch[0],val_loss:2.1267,val_acc:0.3707
# Epoch[0],val_loss:2.1258,val_acc:0.3721
# Epoch[0],val_loss:2.1248,val_acc:0.3731
# Epoch[0],val_loss:2.1239,val_acc:0.3742
# Epoch[0],val_loss:2.1229,val_acc:0.3748
# Epoch[0],val_loss:2.1219,val_acc:0.3780
# Epoch[0],val_loss:2.1209,val_acc:0.3792
# Epoch[0],val_loss:2.1200,val_acc:0.3810
# Epoch[0],val_loss:2.1191,val_acc:0.3822
# Epoch[0],val_loss:2.1181,val_acc:0.3837
# Epoch[0],val_loss:2.1174,val_acc:0.3859
# Epoch[0],val_loss:2.1165,val_acc:0.3874
# Epoch[0],val_loss:2.1156,val_acc:0.3886
# Epoch[0],val_loss:2.1147,val_acc:0.3905
# Epoch[0],val_loss:2.1138,val_acc:0.3918
# Epoch[0],val_loss:2.1129,val_acc:0.3938
# Epoch[0],val_loss:2.1119,val_acc:0.3960
# Epoch[0],val_loss:2.1110,val_acc:0.3976
# Epoch[0],val_loss:2.1101,val_acc:0.3994
# Epoch[0],val_loss:2.1091,val_acc:0.4006
# Epoch[0],val_loss:2.1081,val_acc:0.4026
# Epoch[0],val_loss:2.1073,val_acc:0.4039
# Epoch[0],val_loss:2.1062,val_acc:0.4051
# Epoch[0],val_loss:2.1052,val_acc:0.4071
# Epoch[0],val_loss:2.1043,val_acc:0.4091
# Epoch[0],val_loss:2.1033,val_acc:0.4113
# Epoch[0],val_loss:2.1022,val_acc:0.4129
# Epoch[0],val_loss:2.1014,val_acc:0.4143
# Epoch[0],val_loss:2.1005,val_acc:0.4159
# Epoch[0],val_loss:2.0996,val_acc:0.4170
# Epoch[0],val_loss:2.0986,val_acc:0.4182
# Epoch[0],val_loss:2.0976,val_acc:0.4184
# Epoch[0],val_loss:2.0966,val_acc:0.4205
# Epoch[0],val_loss:2.0957,val_acc:0.4224
# Epoch[0],val_loss:2.0949,val_acc:0.4238
# Epoch[0],val_loss:2.0938,val_acc:0.4261
# Epoch[0],val_loss:2.0929,val_acc:0.4271
# Epoch[0],val_loss:2.0920,val_acc:0.4279
# Epoch[0],val_loss:2.0911,val_acc:0.4300
# Epoch[0],val_loss:2.0902,val_acc:0.4304
# Epoch[0],val_loss:2.0892,val_acc:0.4326
# Epoch[0],val_loss:2.0882,val_acc:0.4333
# Epoch[0],val_loss:2.0872,val_acc:0.4348
# Epoch[0],val_loss:2.0863,val_acc:0.4363
# Epoch[0],val_loss:2.0854,val_acc:0.4376
# Epoch[0],val_loss:2.0846,val_acc:0.4384
# Epoch[0],val_loss:2.0837,val_acc:0.4408
# Epoch[0],val_loss:2.0829,val_acc:0.4419
# Epoch[0],val_loss:2.0821,val_acc:0.4415
# Epoch[0],val_loss:2.0812,val_acc:0.4425
# Epoch[0],val_loss:2.0803,val_acc:0.4441
# Epoch[0],val_loss:2.0794,val_acc:0.4463
# Epoch[0],val_loss:2.0784,val_acc:0.4487
# Epoch[0],val_loss:2.0775,val_acc:0.4498
# Epoch[0],val_loss:2.0766,val_acc:0.4518
# Epoch[0],val_loss:2.0757,val_acc:0.4544
# Epoch[0],val_loss:2.0748,val_acc:0.4553
# Epoch[0],val_loss:2.0739,val_acc:0.4570
# Epoch[0],val_loss:2.0730,val_acc:0.4576
# Epoch[0],val_loss:2.0721,val_acc:0.4599
# Epoch[0],val_loss:2.0711,val_acc:0.4619
# Epoch[0],val_loss:2.0702,val_acc:0.4634
# Epoch[0],val_loss:2.0693,val_acc:0.4632
# Epoch[0],val_loss:2.0685,val_acc:0.4645
# Epoch[0],val_loss:2.0677,val_acc:0.4664
# Epoch[0],val_loss:2.0668,val_acc:0.4684
# Epoch[0],val_loss:2.0659,val_acc:0.4702
# Epoch[0],val_loss:2.0650,val_acc:0.4710
# Epoch[0],val_loss:2.0642,val_acc:0.4709
# Epoch[0],val_loss:2.0633,val_acc:0.4717
# Epoch[0],val_loss:2.0624,val_acc:0.4725
# Epoch[0],val_loss:2.0615,val_acc:0.4735
# Epoch[0],val_loss:2.0606,val_acc:0.4747
# Epoch[0],val_loss:2.0598,val_acc:0.4770
# Epoch[0],val_loss:2.0589,val_acc:0.4786
# Epoch[0],val_loss:2.0581,val_acc:0.4795
# Epoch[0],val_loss:2.0573,val_acc:0.4805
# Epoch[0],val_loss:2.0564,val_acc:0.4826
# Epoch[0],val_loss:2.0556,val_acc:0.4834
# Epoch[0],val_loss:2.0548,val_acc:0.4860
# Epoch[0],val_loss:2.0539,val_acc:0.4867
# Epoch[0],val_loss:2.0530,val_acc:0.4883
# Epoch[0],val_loss:2.0521,val_acc:0.4898
# Epoch[0],val_loss:2.0512,val_acc:0.4913
# Epoch[0],val_loss:2.0503,val_acc:0.4934
# Epoch[0],val_loss:2.0495,val_acc:0.4932
# Epoch[0],val_loss:2.0485,val_acc:0.4952
# Epoch[0],val_loss:2.0477,val_acc:0.4954
# Epoch[0],val_loss:2.0468,val_acc:0.4969
# Epoch[0],val_loss:2.0461,val_acc:0.4982
# Epoch[0],val_loss:2.0451,val_acc:0.4992
# Epoch[0],val_loss:2.0442,val_acc:0.5001
# Epoch[0],val_loss:2.0432,val_acc:0.5008
# Epoch[0],val_loss:2.0423,val_acc:0.5015
# Epoch[0],val_loss:2.0414,val_acc:0.5037
# Epoch[0],val_loss:2.0406,val_acc:0.5045
# Epoch[0],val_loss:2.0397,val_acc:0.5061
# Epoch[0],val_loss:2.0387,val_acc:0.5067
# Epoch[0],val_loss:2.0380,val_acc:0.5067
# Epoch[0],val_loss:2.0372,val_acc:0.5086
# Epoch[0],val_loss:2.0364,val_acc:0.5091
# Epoch[0],val_loss:2.0355,val_acc:0.5101
# Epoch[0],val_loss:2.0346,val_acc:0.5110
# Epoch[0],val_loss:2.0338,val_acc:0.5122
# Epoch[0],val_loss:2.0329,val_acc:0.5138
# Epoch[0],val_loss:2.0320,val_acc:0.5148
# Epoch[0],val_loss:2.0312,val_acc:0.5153
# Epoch[0],val_loss:2.0304,val_acc:0.5163
# Epoch[0],val_loss:2.0295,val_acc:0.5176
# Epoch[0],val_loss:2.0286,val_acc:0.5181
# Epoch[0],val_loss:2.0278,val_acc:0.5188
# Epoch[0],val_loss:2.0268,val_acc:0.5209
# Epoch[0],val_loss:2.0261,val_acc:0.5225
# Epoch[0],val_loss:2.0252,val_acc:0.5239
# Epoch[0],val_loss:2.0244,val_acc:0.5236
# Epoch[0],val_loss:2.0235,val_acc:0.5246
# Epoch[0],val_loss:2.0227,val_acc:0.5268
# Epoch[0],val_loss:2.0217,val_acc:0.5277
# Epoch[0],val_loss:2.0208,val_acc:0.5286
# Epoch[0],val_loss:2.0199,val_acc:0.5297
# Epoch[0],val_loss:2.0191,val_acc:0.5299
# Epoch[0],val_loss:2.0183,val_acc:0.5311
# Epoch[0],val_loss:2.0174,val_acc:0.5314
# Epoch[0],val_loss:2.0167,val_acc:0.5312
# Epoch[0],val_loss:2.0158,val_acc:0.5308
# Epoch[0],val_loss:2.0150,val_acc:0.5321
# Epoch[0],val_loss:2.0141,val_acc:0.5331
# Epoch[0],val_loss:2.0133,val_acc:0.5341
# Epoch[0],val_loss:2.0124,val_acc:0.5349
# Epoch[0],val_loss:2.0116,val_acc:0.5352
# Epoch[0],val_loss:2.0108,val_acc:0.5359
# Epoch[0],val_loss:2.0099,val_acc:0.5368
# Epoch[0],val_loss:2.0091,val_acc:0.5374
# Epoch[0],val_loss:2.0082,val_acc:0.5384
# Epoch[0],val_loss:2.0073,val_acc:0.5388
# Epoch[0],val_loss:2.0065,val_acc:0.5399
# Epoch[0],val_loss:2.0057,val_acc:0.5421
# Epoch[0],val_loss:2.0048,val_acc:0.5421
# Epoch[0],val_loss:2.0039,val_acc:0.5435
# Epoch[0],val_loss:2.0030,val_acc:0.5443
# Epoch[0],val_loss:2.0021,val_acc:0.5457
# Epoch[0],val_loss:2.0013,val_acc:0.5464
# Epoch[0],val_loss:2.0005,val_acc:0.5477
# Epoch[0],val_loss:1.9997,val_acc:0.5494
# Epoch[0],val_loss:1.9988,val_acc:0.5508
# Epoch[0],val_loss:1.9979,val_acc:0.5507
# Epoch[0],val_loss:1.9971,val_acc:0.5522
# Epoch[0],val_loss:1.9962,val_acc:0.5530
# Epoch[0],val_loss:1.9953,val_acc:0.5550
# Epoch[0],val_loss:1.9944,val_acc:0.5564
# Epoch[0],val_loss:1.9937,val_acc:0.5570
# Epoch[0],val_loss:1.9928,val_acc:0.5592
# Epoch[0],val_loss:1.9919,val_acc:0.5591
# Epoch[0],val_loss:1.9911,val_acc:0.5598
# Epoch[0],val_loss:1.9904,val_acc:0.5589
# Epoch[0],val_loss:1.9896,val_acc:0.5596
# Epoch[0],val_loss:1.9888,val_acc:0.5610
# Epoch[0],val_loss:1.9880,val_acc:0.5612
# Epoch[0],val_loss:1.9872,val_acc:0.5625
# Epoch[0],val_loss:1.9864,val_acc:0.5634
# Epoch[0],val_loss:1.9857,val_acc:0.5641
# Epoch[0],val_loss:1.9848,val_acc:0.5645
# Epoch[0],val_loss:1.9840,val_acc:0.5667
# Epoch[0],val_loss:1.9832,val_acc:0.5668
# Epoch[0],val_loss:1.9823,val_acc:0.5674
# Epoch[0],val_loss:1.9815,val_acc:0.5685
# Epoch[0],val_loss:1.9807,val_acc:0.5700
# Epoch[0],val_loss:1.9799,val_acc:0.5720
# Epoch[0],val_loss:1.9792,val_acc:0.5731
# Epoch[0],val_loss:1.9784,val_acc:0.5738
# Epoch[0],val_loss:1.9776,val_acc:0.5736
# Epoch[0],val_loss:1.9767,val_acc:0.5744
# Epoch[0],val_loss:1.9759,val_acc:0.5742
# Epoch[0],val_loss:1.9751,val_acc:0.5743
# Epoch[0],val_loss:1.9743,val_acc:0.5749
# Epoch[0],val_loss:1.9735,val_acc:0.5754
# Epoch[0],val_loss:1.9726,val_acc:0.5771
# Epoch[0],val_loss:1.9717,val_acc:0.5794
# Epoch[0],val_loss:1.9709,val_acc:0.5802
# Epoch[0],val_loss:1.9700,val_acc:0.5823
# Epoch[0],val_loss:1.9692,val_acc:0.5841
# Epoch[0],val_loss:1.9684,val_acc:0.5850
# Epoch[0],val_loss:1.9677,val_acc:0.5856
# Epoch[0],val_loss:1.9668,val_acc:0.5858
# Epoch[0],val_loss:1.9660,val_acc:0.5867
# Epoch[0],val_loss:1.9652,val_acc:0.5892
# Epoch[0],val_loss:1.9645,val_acc:0.5893
# Epoch[0],val_loss:1.9637,val_acc:0.5902
# Epoch[0],val_loss:1.9629,val_acc:0.5915
# Epoch[0],val_loss:1.9621,val_acc:0.5930
# Epoch[0],val_loss:1.9613,val_acc:0.5941
# Epoch[0],val_loss:1.9605,val_acc:0.5950
# Epoch[0],val_loss:1.9596,val_acc:0.5953
# Epoch[0],val_loss:1.9589,val_acc:0.5965
# Epoch[0],val_loss:1.9580,val_acc:0.5979
# Epoch[0],val_loss:1.9572,val_acc:0.5983
# Epoch[0],val_loss:1.9565,val_acc:0.5990
# Epoch[0],val_loss:1.9557,val_acc:0.5997
# Epoch[0],val_loss:1.9549,val_acc:0.5999
# Epoch[0],val_loss:1.9540,val_acc:0.6009
# Epoch[0],val_loss:1.9533,val_acc:0.6017
# Epoch[0],val_loss:1.9525,val_acc:0.6025
# Epoch[0],val_loss:1.9516,val_acc:0.6041
# Epoch[0],val_loss:1.9510,val_acc:0.6048
# Epoch[0],val_loss:1.9502,val_acc:0.6074
# Epoch[1],val_loss:1.9493,val_acc:0.6071
# Epoch[1],val_loss:1.9487,val_acc:0.6073
# Epoch[1],val_loss:1.9479,val_acc:0.6074
# Epoch[1],val_loss:1.9470,val_acc:0.6092
# Epoch[1],val_loss:1.9462,val_acc:0.6086
# Epoch[1],val_loss:1.9455,val_acc:0.6095
# Epoch[1],val_loss:1.9447,val_acc:0.6103
# Epoch[1],val_loss:1.9438,val_acc:0.6098
# Epoch[1],val_loss:1.9430,val_acc:0.6114
# Epoch[1],val_loss:1.9421,val_acc:0.6121
# Epoch[1],val_loss:1.9414,val_acc:0.6139
# Epoch[1],val_loss:1.9405,val_acc:0.6137
# Epoch[1],val_loss:1.9397,val_acc:0.6146
# Epoch[1],val_loss:1.9390,val_acc:0.6152
# Epoch[1],val_loss:1.9382,val_acc:0.6156
# Epoch[1],val_loss:1.9375,val_acc:0.6171
# Epoch[1],val_loss:1.9367,val_acc:0.6175
# Epoch[1],val_loss:1.9359,val_acc:0.6186
# Epoch[1],val_loss:1.9353,val_acc:0.6185
# Epoch[1],val_loss:1.9344,val_acc:0.6192
# Epoch[1],val_loss:1.9337,val_acc:0.6205
# Epoch[1],val_loss:1.9330,val_acc:0.6210
# Epoch[1],val_loss:1.9322,val_acc:0.6228
# Epoch[1],val_loss:1.9314,val_acc:0.6237
# Epoch[1],val_loss:1.9306,val_acc:0.6239
# Epoch[1],val_loss:1.9298,val_acc:0.6250
# Epoch[1],val_loss:1.9289,val_acc:0.6257
# Epoch[1],val_loss:1.9281,val_acc:0.6260
# Epoch[1],val_loss:1.9274,val_acc:0.6266
# Epoch[1],val_loss:1.9266,val_acc:0.6278
# Epoch[1],val_loss:1.9259,val_acc:0.6274
# Epoch[1],val_loss:1.9250,val_acc:0.6282
# Epoch[1],val_loss:1.9243,val_acc:0.6285
# Epoch[1],val_loss:1.9235,val_acc:0.6295
# Epoch[1],val_loss:1.9227,val_acc:0.6295
# Epoch[1],val_loss:1.9219,val_acc:0.6298
# Epoch[1],val_loss:1.9210,val_acc:0.6295
# Epoch[1],val_loss:1.9203,val_acc:0.6299
# Epoch[1],val_loss:1.9196,val_acc:0.6310
# Epoch[1],val_loss:1.9188,val_acc:0.6311
# Epoch[1],val_loss:1.9180,val_acc:0.6315
# Epoch[1],val_loss:1.9172,val_acc:0.6324
# Epoch[1],val_loss:1.9164,val_acc:0.6330
# Epoch[1],val_loss:1.9156,val_acc:0.6340
# Epoch[1],val_loss:1.9148,val_acc:0.6350
# Epoch[1],val_loss:1.9141,val_acc:0.6356
# Epoch[1],val_loss:1.9133,val_acc:0.6362
# Epoch[1],val_loss:1.9125,val_acc:0.6366
# Epoch[1],val_loss:1.9116,val_acc:0.6373
# Epoch[1],val_loss:1.9108,val_acc:0.6381
# Epoch[1],val_loss:1.9101,val_acc:0.6385
# Epoch[1],val_loss:1.9093,val_acc:0.6378
# Epoch[1],val_loss:1.9085,val_acc:0.6379
# Epoch[1],val_loss:1.9077,val_acc:0.6386
# Epoch[1],val_loss:1.9069,val_acc:0.6395
# Epoch[1],val_loss:1.9062,val_acc:0.6403
# Epoch[1],val_loss:1.9054,val_acc:0.6410
# Epoch[1],val_loss:1.9046,val_acc:0.6414
# Epoch[1],val_loss:1.9038,val_acc:0.6426
# Epoch[1],val_loss:1.9030,val_acc:0.6421
# Epoch[1],val_loss:1.9023,val_acc:0.6431
# Epoch[1],val_loss:1.9016,val_acc:0.6430
# Epoch[1],val_loss:1.9008,val_acc:0.6439
# Epoch[1],val_loss:1.9000,val_acc:0.6444
# Epoch[1],val_loss:1.8992,val_acc:0.6443
# Epoch[1],val_loss:1.8984,val_acc:0.6440
# Epoch[1],val_loss:1.8978,val_acc:0.6451
# Epoch[1],val_loss:1.8971,val_acc:0.6453
# Epoch[1],val_loss:1.8964,val_acc:0.6461
# Epoch[1],val_loss:1.8957,val_acc:0.6467
# Epoch[1],val_loss:1.8949,val_acc:0.6472
# Epoch[1],val_loss:1.8941,val_acc:0.6477
# Epoch[1],val_loss:1.8934,val_acc:0.6489
# Epoch[1],val_loss:1.8927,val_acc:0.6492
# Epoch[1],val_loss:1.8919,val_acc:0.6499
# Epoch[1],val_loss:1.8912,val_acc:0.6501
# Epoch[1],val_loss:1.8904,val_acc:0.6504
# Epoch[1],val_loss:1.8897,val_acc:0.6504
# Epoch[1],val_loss:1.8889,val_acc:0.6504
# Epoch[1],val_loss:1.8882,val_acc:0.6506
# Epoch[1],val_loss:1.8874,val_acc:0.6510
# Epoch[1],val_loss:1.8867,val_acc:0.6516
# Epoch[1],val_loss:1.8859,val_acc:0.6519
# Epoch[1],val_loss:1.8852,val_acc:0.6516
# Epoch[1],val_loss:1.8845,val_acc:0.6538
# Epoch[1],val_loss:1.8837,val_acc:0.6536
# Epoch[1],val_loss:1.8829,val_acc:0.6542
# Epoch[1],val_loss:1.8821,val_acc:0.6557
# Epoch[1],val_loss:1.8813,val_acc:0.6557
# Epoch[1],val_loss:1.8806,val_acc:0.6563
# Epoch[1],val_loss:1.8798,val_acc:0.6568
# Epoch[1],val_loss:1.8790,val_acc:0.6574
# Epoch[1],val_loss:1.8783,val_acc:0.6579
# Epoch[1],val_loss:1.8776,val_acc:0.6580
# Epoch[1],val_loss:1.8769,val_acc:0.6578
# Epoch[1],val_loss:1.8761,val_acc:0.6575
# Epoch[1],val_loss:1.8754,val_acc:0.6579
# Epoch[1],val_loss:1.8747,val_acc:0.6589
# Epoch[1],val_loss:1.8740,val_acc:0.6593
# Epoch[1],val_loss:1.8733,val_acc:0.6599
# Epoch[1],val_loss:1.8726,val_acc:0.6609
# Epoch[1],val_loss:1.8718,val_acc:0.6617
# Epoch[1],val_loss:1.8711,val_acc:0.6617
# Epoch[1],val_loss:1.8703,val_acc:0.6622
# Epoch[1],val_loss:1.8695,val_acc:0.6623
# Epoch[1],val_loss:1.8687,val_acc:0.6632
# Epoch[1],val_loss:1.8679,val_acc:0.6626
# Epoch[1],val_loss:1.8672,val_acc:0.6638
# Epoch[1],val_loss:1.8665,val_acc:0.6638
# Epoch[1],val_loss:1.8658,val_acc:0.6642
# Epoch[1],val_loss:1.8651,val_acc:0.6655
# Epoch[1],val_loss:1.8643,val_acc:0.6664
# Epoch[1],val_loss:1.8636,val_acc:0.6659
# Epoch[1],val_loss:1.8629,val_acc:0.6660
# Epoch[1],val_loss:1.8621,val_acc:0.6672
# Epoch[1],val_loss:1.8614,val_acc:0.6666
# Epoch[1],val_loss:1.8607,val_acc:0.6678
# Epoch[1],val_loss:1.8600,val_acc:0.6673
# Epoch[1],val_loss:1.8592,val_acc:0.6677
# Epoch[1],val_loss:1.8584,val_acc:0.6691
# Epoch[1],val_loss:1.8577,val_acc:0.6687
# Epoch[1],val_loss:1.8570,val_acc:0.6686
# Epoch[1],val_loss:1.8563,val_acc:0.6690
# Epoch[1],val_loss:1.8556,val_acc:0.6704
# Epoch[1],val_loss:1.8549,val_acc:0.6707
# Epoch[1],val_loss:1.8541,val_acc:0.6718
# Epoch[1],val_loss:1.8535,val_acc:0.6720
# Epoch[1],val_loss:1.8528,val_acc:0.6714
# Epoch[1],val_loss:1.8521,val_acc:0.6716
# Epoch[1],val_loss:1.8513,val_acc:0.6721
# Epoch[1],val_loss:1.8505,val_acc:0.6728
# Epoch[1],val_loss:1.8499,val_acc:0.6737
# Epoch[1],val_loss:1.8492,val_acc:0.6741
# Epoch[1],val_loss:1.8485,val_acc:0.6745
# Epoch[1],val_loss:1.8479,val_acc:0.6750
# Epoch[1],val_loss:1.8472,val_acc:0.6756
# Epoch[1],val_loss:1.8465,val_acc:0.6756
# Epoch[1],val_loss:1.8458,val_acc:0.6761
# Epoch[1],val_loss:1.8451,val_acc:0.6766
# Epoch[1],val_loss:1.8445,val_acc:0.6770
# Epoch[1],val_loss:1.8437,val_acc:0.6772
# Epoch[1],val_loss:1.8430,val_acc:0.6776
# Epoch[1],val_loss:1.8423,val_acc:0.6787
# Epoch[1],val_loss:1.8415,val_acc:0.6801
# Epoch[1],val_loss:1.8408,val_acc:0.6799
# Epoch[1],val_loss:1.8400,val_acc:0.6804
# Epoch[1],val_loss:1.8393,val_acc:0.6811
# Epoch[1],val_loss:1.8385,val_acc:0.6826
# Epoch[1],val_loss:1.8379,val_acc:0.6832
# Epoch[1],val_loss:1.8372,val_acc:0.6836
# Epoch[1],val_loss:1.8365,val_acc:0.6845
# Epoch[1],val_loss:1.8357,val_acc:0.6830
# Epoch[1],val_loss:1.8350,val_acc:0.6842
# Epoch[1],val_loss:1.8344,val_acc:0.6850
# Epoch[1],val_loss:1.8337,val_acc:0.6849
# Epoch[1],val_loss:1.8330,val_acc:0.6848
# Epoch[1],val_loss:1.8322,val_acc:0.6846
# Epoch[1],val_loss:1.8315,val_acc:0.6852
# Epoch[1],val_loss:1.8309,val_acc:0.6854
# Epoch[1],val_loss:1.8302,val_acc:0.6860
# Epoch[1],val_loss:1.8295,val_acc:0.6865
# Epoch[1],val_loss:1.8288,val_acc:0.6874
# Epoch[1],val_loss:1.8281,val_acc:0.6881
# Epoch[1],val_loss:1.8274,val_acc:0.6886
# Epoch[1],val_loss:1.8266,val_acc:0.6890
# Epoch[1],val_loss:1.8259,val_acc:0.6893
# Epoch[1],val_loss:1.8253,val_acc:0.6898
# Epoch[1],val_loss:1.8246,val_acc:0.6897
# Epoch[1],val_loss:1.8239,val_acc:0.6891
# Epoch[1],val_loss:1.8232,val_acc:0.6894
# Epoch[1],val_loss:1.8226,val_acc:0.6900
# Epoch[1],val_loss:1.8218,val_acc:0.6903
# Epoch[1],val_loss:1.8211,val_acc:0.6910
# Epoch[1],val_loss:1.8204,val_acc:0.6916
# Epoch[1],val_loss:1.8197,val_acc:0.6914
# Epoch[1],val_loss:1.8190,val_acc:0.6914
# Epoch[1],val_loss:1.8183,val_acc:0.6922
# Epoch[1],val_loss:1.8175,val_acc:0.6923
# Epoch[1],val_loss:1.8168,val_acc:0.6923
# Epoch[1],val_loss:1.8160,val_acc:0.6919
# Epoch[1],val_loss:1.8153,val_acc:0.6914
# Epoch[1],val_loss:1.8146,val_acc:0.6917
# Epoch[1],val_loss:1.8139,val_acc:0.6922
# Epoch[1],val_loss:1.8133,val_acc:0.6920
# Epoch[1],val_loss:1.8126,val_acc:0.6929
# Epoch[1],val_loss:1.8119,val_acc:0.6934
# Epoch[1],val_loss:1.8112,val_acc:0.6934
# Epoch[1],val_loss:1.8105,val_acc:0.6941
# Epoch[1],val_loss:1.8099,val_acc:0.6949
# Epoch[1],val_loss:1.8092,val_acc:0.6948
# Epoch[1],val_loss:1.8085,val_acc:0.6951
# Epoch[1],val_loss:1.8078,val_acc:0.6946
# Epoch[1],val_loss:1.8071,val_acc:0.6958
# Epoch[1],val_loss:1.8064,val_acc:0.6961
# Epoch[1],val_loss:1.8057,val_acc:0.6971
# Epoch[1],val_loss:1.8051,val_acc:0.6981
# Epoch[1],val_loss:1.8043,val_acc:0.6986
# Epoch[1],val_loss:1.8035,val_acc:0.6990
# Epoch[1],val_loss:1.8028,val_acc:0.6992
# Epoch[1],val_loss:1.8021,val_acc:0.6995
# Epoch[1],val_loss:1.8014,val_acc:0.6995
# Epoch[1],val_loss:1.8007,val_acc:0.7003
# Epoch[1],val_loss:1.8000,val_acc:0.7002
# Epoch[1],val_loss:1.7993,val_acc:0.7006
# Epoch[1],val_loss:1.7986,val_acc:0.7004
# Epoch[1],val_loss:1.7979,val_acc:0.7003
# Epoch[1],val_loss:1.7972,val_acc:0.7007
# Epoch[1],val_loss:1.7965,val_acc:0.7011
# Epoch[1],val_loss:1.7958,val_acc:0.7016
# Epoch[1],val_loss:1.7952,val_acc:0.7033
# Epoch[1],val_loss:1.7945,val_acc:0.7031
# Epoch[1],val_loss:1.7938,val_acc:0.7035
# Epoch[1],val_loss:1.7931,val_acc:0.7041
# Epoch[1],val_loss:1.7925,val_acc:0.7045
# Epoch[1],val_loss:1.7918,val_acc:0.7045
# Epoch[1],val_loss:1.7911,val_acc:0.7048
# Epoch[1],val_loss:1.7904,val_acc:0.7051
# Epoch[1],val_loss:1.7897,val_acc:0.7060
# Epoch[1],val_loss:1.7890,val_acc:0.7064
# Epoch[1],val_loss:1.7883,val_acc:0.7070
# Epoch[1],val_loss:1.7877,val_acc:0.7079
# Epoch[1],val_loss:1.7871,val_acc:0.7073
# Epoch[1],val_loss:1.7864,val_acc:0.7076
# Epoch[1],val_loss:1.7858,val_acc:0.7081
# Epoch[1],val_loss:1.7851,val_acc:0.7080
# Epoch[1],val_loss:1.7844,val_acc:0.7085
# Epoch[1],val_loss:1.7837,val_acc:0.7087
# Epoch[1],val_loss:1.7830,val_acc:0.7098
# Epoch[1],val_loss:1.7823,val_acc:0.7098
# Epoch[1],val_loss:1.7817,val_acc:0.7098
# Epoch[1],val_loss:1.7811,val_acc:0.7097
# Epoch[1],val_loss:1.7804,val_acc:0.7098
# Epoch[1],val_loss:1.7797,val_acc:0.7102
# Epoch[1],val_loss:1.7790,val_acc:0.7100
# Epoch[1],val_loss:1.7783,val_acc:0.7104
# Epoch[1],val_loss:1.7776,val_acc:0.7113
# Epoch[1],val_loss:1.7769,val_acc:0.7117
# Epoch[1],val_loss:1.7762,val_acc:0.7127
# Epoch[1],val_loss:1.7756,val_acc:0.7123
# Epoch[1],val_loss:1.7749,val_acc:0.7124
# Epoch[1],val_loss:1.7742,val_acc:0.7128
# Epoch[1],val_loss:1.7735,val_acc:0.7129
# Epoch[1],val_loss:1.7728,val_acc:0.7132
# Epoch[1],val_loss:1.7721,val_acc:0.7136
# Epoch[1],val_loss:1.7715,val_acc:0.7138
# Epoch[1],val_loss:1.7708,val_acc:0.7142
# Epoch[1],val_loss:1.7702,val_acc:0.7142
# Epoch[1],val_loss:1.7695,val_acc:0.7143
# Epoch[1],val_loss:1.7689,val_acc:0.7158
# Epoch[1],val_loss:1.7682,val_acc:0.7157
# Epoch[1],val_loss:1.7675,val_acc:0.7161
# Epoch[1],val_loss:1.7668,val_acc:0.7158
# Epoch[1],val_loss:1.7662,val_acc:0.7159
# Epoch[1],val_loss:1.7656,val_acc:0.7165
# Epoch[1],val_loss:1.7649,val_acc:0.7173
# Epoch[1],val_loss:1.7642,val_acc:0.7168
# Epoch[1],val_loss:1.7636,val_acc:0.7177
# Epoch[1],val_loss:1.7630,val_acc:0.7188
# Epoch[1],val_loss:1.7623,val_acc:0.7191
# Epoch[1],val_loss:1.7616,val_acc:0.7191
# Epoch[1],val_loss:1.7609,val_acc:0.7199
# Epoch[1],val_loss:1.7603,val_acc:0.7196
# Epoch[1],val_loss:1.7596,val_acc:0.7196
# Epoch[1],val_loss:1.7591,val_acc:0.7201
# Epoch[1],val_loss:1.7584,val_acc:0.7201
# Epoch[1],val_loss:1.7578,val_acc:0.7201
# Epoch[1],val_loss:1.7571,val_acc:0.7208
# Epoch[1],val_loss:1.7565,val_acc:0.7210
# Epoch[1],val_loss:1.7559,val_acc:0.7215
# Epoch[1],val_loss:1.7553,val_acc:0.7216
# Epoch[1],val_loss:1.7547,val_acc:0.7219
# Epoch[1],val_loss:1.7541,val_acc:0.7213
# Epoch[1],val_loss:1.7535,val_acc:0.7213
# Epoch[1],val_loss:1.7528,val_acc:0.7221
# Epoch[1],val_loss:1.7522,val_acc:0.7218
# Epoch[1],val_loss:1.7516,val_acc:0.7221
# Epoch[1],val_loss:1.7510,val_acc:0.7223
# Epoch[1],val_loss:1.7503,val_acc:0.7224
# Epoch[1],val_loss:1.7497,val_acc:0.7224
# Epoch[1],val_loss:1.7490,val_acc:0.7226
# Epoch[1],val_loss:1.7484,val_acc:0.7227
# Epoch[1],val_loss:1.7477,val_acc:0.7232
# Epoch[1],val_loss:1.7470,val_acc:0.7236
# Epoch[1],val_loss:1.7464,val_acc:0.7242
# Epoch[1],val_loss:1.7457,val_acc:0.7239
# Epoch[1],val_loss:1.7451,val_acc:0.7255
# Epoch[1],val_loss:1.7444,val_acc:0.7261
# Epoch[1],val_loss:1.7438,val_acc:0.7262
# Epoch[1],val_loss:1.7431,val_acc:0.7260
# Epoch[1],val_loss:1.7425,val_acc:0.7260
# Epoch[1],val_loss:1.7419,val_acc:0.7261
# Epoch[1],val_loss:1.7412,val_acc:0.7257
# Epoch[1],val_loss:1.7406,val_acc:0.7261
# Epoch[1],val_loss:1.7400,val_acc:0.7265
# Epoch[1],val_loss:1.7394,val_acc:0.7266
# Epoch[1],val_loss:1.7388,val_acc:0.7277
# Epoch[1],val_loss:1.7382,val_acc:0.7280
# Epoch[1],val_loss:1.7376,val_acc:0.7283
# Epoch[1],val_loss:1.7370,val_acc:0.7281
# Epoch[1],val_loss:1.7363,val_acc:0.7282
# Epoch[1],val_loss:1.7357,val_acc:0.7283
# Epoch[1],val_loss:1.7350,val_acc:0.7285
# Epoch[1],val_loss:1.7344,val_acc:0.7288
# Epoch[1],val_loss:1.7338,val_acc:0.7283
# Epoch[1],val_loss:1.7332,val_acc:0.7290
# Epoch[1],val_loss:1.7326,val_acc:0.7300
# Epoch[1],val_loss:1.7319,val_acc:0.7295
# Epoch[1],val_loss:1.7314,val_acc:0.7293
# Epoch[1],val_loss:1.7307,val_acc:0.7291
# Epoch[1],val_loss:1.7300,val_acc:0.7290
# Epoch[1],val_loss:1.7294,val_acc:0.7295
# Epoch[1],val_loss:1.7288,val_acc:0.7291
# Epoch[1],val_loss:1.7282,val_acc:0.7296
# Epoch[1],val_loss:1.7275,val_acc:0.7302
# Epoch[1],val_loss:1.7268,val_acc:0.7307
# Epoch[1],val_loss:1.7262,val_acc:0.7303
# Epoch[1],val_loss:1.7256,val_acc:0.7308
# Epoch[1],val_loss:1.7250,val_acc:0.7311
# Epoch[1],val_loss:1.7243,val_acc:0.7309
# Epoch[1],val_loss:1.7237,val_acc:0.7312
# Epoch[1],val_loss:1.7230,val_acc:0.7307
# Epoch[1],val_loss:1.7223,val_acc:0.7308
# Epoch[1],val_loss:1.7217,val_acc:0.7311
# Epoch[1],val_loss:1.7211,val_acc:0.7309
# Epoch[1],val_loss:1.7205,val_acc:0.7315
# Epoch[1],val_loss:1.7199,val_acc:0.7315
# Epoch[1],val_loss:1.7193,val_acc:0.7319
# Epoch[1],val_loss:1.7187,val_acc:0.7318
# Epoch[1],val_loss:1.7181,val_acc:0.7318
# Epoch[1],val_loss:1.7176,val_acc:0.7323
# Epoch[1],val_loss:1.7170,val_acc:0.7324
# Epoch[1],val_loss:1.7163,val_acc:0.7326
# Epoch[1],val_loss:1.7157,val_acc:0.7324
# Epoch[1],val_loss:1.7151,val_acc:0.7327
# Epoch[1],val_loss:1.7146,val_acc:0.7331
# Epoch[1],val_loss:1.7139,val_acc:0.7330
# Epoch[1],val_loss:1.7133,val_acc:0.7330
# Epoch[1],val_loss:1.7127,val_acc:0.7336
# Epoch[1],val_loss:1.7121,val_acc:0.7332
# Epoch[1],val_loss:1.7115,val_acc:0.7336
# Epoch[1],val_loss:1.7108,val_acc:0.7337
# Epoch[1],val_loss:1.7102,val_acc:0.7337
# Epoch[1],val_loss:1.7097,val_acc:0.7335
# Epoch[1],val_loss:1.7090,val_acc:0.7339
# Epoch[1],val_loss:1.7084,val_acc:0.7339
# Epoch[1],val_loss:1.7078,val_acc:0.7340
# Epoch[1],val_loss:1.7072,val_acc:0.7345
# Epoch[1],val_loss:1.7066,val_acc:0.7342
# Epoch[1],val_loss:1.7060,val_acc:0.7341
# Epoch[1],val_loss:1.7053,val_acc:0.7346
# Epoch[1],val_loss:1.7047,val_acc:0.7348
# Epoch[1],val_loss:1.7041,val_acc:0.7343
# Epoch[1],val_loss:1.7034,val_acc:0.7344
# Epoch[1],val_loss:1.7028,val_acc:0.7346
# Epoch[1],val_loss:1.7021,val_acc:0.7344
# Epoch[1],val_loss:1.7016,val_acc:0.7344
# Epoch[1],val_loss:1.7009,val_acc:0.7348
# Epoch[1],val_loss:1.7003,val_acc:0.7347
# Epoch[1],val_loss:1.6997,val_acc:0.7352
# Epoch[1],val_loss:1.6991,val_acc:0.7344
# Epoch[1],val_loss:1.6985,val_acc:0.7356
# Epoch[1],val_loss:1.6980,val_acc:0.7355
# Epoch[1],val_loss:1.6974,val_acc:0.7359
# Epoch[1],val_loss:1.6968,val_acc:0.7363
# Epoch[1],val_loss:1.6962,val_acc:0.7368
# Epoch[1],val_loss:1.6956,val_acc:0.7366
# Epoch[1],val_loss:1.6950,val_acc:0.7373
# Epoch[1],val_loss:1.6944,val_acc:0.7374
# Epoch[1],val_loss:1.6938,val_acc:0.7375
# Epoch[1],val_loss:1.6931,val_acc:0.7380
# Epoch[1],val_loss:1.6925,val_acc:0.7379
# Epoch[1],val_loss:1.6920,val_acc:0.7382
# Epoch[1],val_loss:1.6914,val_acc:0.7384
# Epoch[1],val_loss:1.6907,val_acc:0.7392
# Epoch[1],val_loss:1.6902,val_acc:0.7392
# Epoch[1],val_loss:1.6896,val_acc:0.7399
# Epoch[1],val_loss:1.6890,val_acc:0.7402
# Epoch[1],val_loss:1.6884,val_acc:0.7397
# Epoch[1],val_loss:1.6878,val_acc:0.7394
# Epoch[1],val_loss:1.6872,val_acc:0.7395
# Epoch[1],val_loss:1.6866,val_acc:0.7402
# Epoch[1],val_loss:1.6861,val_acc:0.7408
# Epoch[1],val_loss:1.6855,val_acc:0.7405
# Epoch[1],val_loss:1.6848,val_acc:0.7411
# Epoch[1],val_loss:1.6842,val_acc:0.7409
# Epoch[1],val_loss:1.6836,val_acc:0.7412
# Epoch[1],val_loss:1.6830,val_acc:0.7413
# Epoch[1],val_loss:1.6824,val_acc:0.7409
# Epoch[1],val_loss:1.6819,val_acc:0.7414
# Epoch[1],val_loss:1.6813,val_acc:0.7423
# Epoch[1],val_loss:1.6807,val_acc:0.7424
# Epoch[2],val_loss:1.6801,val_acc:0.7422
# Epoch[2],val_loss:1.6794,val_acc:0.7420
# Epoch[2],val_loss:1.6788,val_acc:0.7416
# Epoch[2],val_loss:1.6782,val_acc:0.7420
# Epoch[2],val_loss:1.6777,val_acc:0.7422
# Epoch[2],val_loss:1.6771,val_acc:0.7424
# Epoch[2],val_loss:1.6765,val_acc:0.7420
# Epoch[2],val_loss:1.6759,val_acc:0.7422
# Epoch[2],val_loss:1.6753,val_acc:0.7413
# Epoch[2],val_loss:1.6747,val_acc:0.7420
# Epoch[2],val_loss:1.6741,val_acc:0.7426
# Epoch[2],val_loss:1.6735,val_acc:0.7425
# Epoch[2],val_loss:1.6729,val_acc:0.7433
# Epoch[2],val_loss:1.6724,val_acc:0.7434
# Epoch[2],val_loss:1.6718,val_acc:0.7432
# Epoch[2],val_loss:1.6712,val_acc:0.7437
# Epoch[2],val_loss:1.6706,val_acc:0.7437
# Epoch[2],val_loss:1.6701,val_acc:0.7442
# Epoch[2],val_loss:1.6695,val_acc:0.7446
# Epoch[2],val_loss:1.6689,val_acc:0.7447
# Epoch[2],val_loss:1.6683,val_acc:0.7451
# Epoch[2],val_loss:1.6678,val_acc:0.7453
# Epoch[2],val_loss:1.6672,val_acc:0.7452
# Epoch[2],val_loss:1.6666,val_acc:0.7457
# Epoch[2],val_loss:1.6661,val_acc:0.7459
# Epoch[2],val_loss:1.6655,val_acc:0.7459
# Epoch[2],val_loss:1.6650,val_acc:0.7463
# Epoch[2],val_loss:1.6644,val_acc:0.7468
# Epoch[2],val_loss:1.6638,val_acc:0.7466
# Epoch[2],val_loss:1.6632,val_acc:0.7467
# Epoch[2],val_loss:1.6626,val_acc:0.7474
# Epoch[2],val_loss:1.6620,val_acc:0.7471
# Epoch[2],val_loss:1.6614,val_acc:0.7473
# Epoch[2],val_loss:1.6609,val_acc:0.7472
# Epoch[2],val_loss:1.6603,val_acc:0.7477
# Epoch[2],val_loss:1.6598,val_acc:0.7479
# Epoch[2],val_loss:1.6592,val_acc:0.7484
# Epoch[2],val_loss:1.6587,val_acc:0.7484
# Epoch[2],val_loss:1.6581,val_acc:0.7486
# Epoch[2],val_loss:1.6575,val_acc:0.7480
# Epoch[2],val_loss:1.6569,val_acc:0.7486
# Epoch[2],val_loss:1.6563,val_acc:0.7487
# Epoch[2],val_loss:1.6557,val_acc:0.7487
# Epoch[2],val_loss:1.6551,val_acc:0.7485
# Epoch[2],val_loss:1.6546,val_acc:0.7484
# Epoch[2],val_loss:1.6540,val_acc:0.7483
# Epoch[2],val_loss:1.6535,val_acc:0.7490
# Epoch[2],val_loss:1.6529,val_acc:0.7496
# Epoch[2],val_loss:1.6523,val_acc:0.7502
# Epoch[2],val_loss:1.6517,val_acc:0.7507
# Epoch[2],val_loss:1.6511,val_acc:0.7505
# Epoch[2],val_loss:1.6506,val_acc:0.7504
# Epoch[2],val_loss:1.6500,val_acc:0.7507
# Epoch[2],val_loss:1.6494,val_acc:0.7504
# Epoch[2],val_loss:1.6489,val_acc:0.7510
# Epoch[2],val_loss:1.6484,val_acc:0.7513
# Epoch[2],val_loss:1.6478,val_acc:0.7516
# Epoch[2],val_loss:1.6472,val_acc:0.7506
# Epoch[2],val_loss:1.6467,val_acc:0.7508
# Epoch[2],val_loss:1.6460,val_acc:0.7515
# Epoch[2],val_loss:1.6454,val_acc:0.7519
# Epoch[2],val_loss:1.6449,val_acc:0.7525
# Epoch[2],val_loss:1.6444,val_acc:0.7527
# Epoch[2],val_loss:1.6438,val_acc:0.7531
# Epoch[2],val_loss:1.6433,val_acc:0.7530
# Epoch[2],val_loss:1.6427,val_acc:0.7533
# Epoch[2],val_loss:1.6421,val_acc:0.7535
# Epoch[2],val_loss:1.6416,val_acc:0.7540
# Epoch[2],val_loss:1.6411,val_acc:0.7540
# Epoch[2],val_loss:1.6405,val_acc:0.7541
# Epoch[2],val_loss:1.6400,val_acc:0.7542
# Epoch[2],val_loss:1.6395,val_acc:0.7543
# Epoch[2],val_loss:1.6389,val_acc:0.7546
# Epoch[2],val_loss:1.6383,val_acc:0.7545
# Epoch[2],val_loss:1.6377,val_acc:0.7546
# Epoch[2],val_loss:1.6372,val_acc:0.7545
# Epoch[2],val_loss:1.6366,val_acc:0.7549
# Epoch[2],val_loss:1.6361,val_acc:0.7552
# Epoch[2],val_loss:1.6356,val_acc:0.7550
# Epoch[2],val_loss:1.6350,val_acc:0.7550
# Epoch[2],val_loss:1.6344,val_acc:0.7552
# Epoch[2],val_loss:1.6339,val_acc:0.7553
# Epoch[2],val_loss:1.6333,val_acc:0.7556
# Epoch[2],val_loss:1.6328,val_acc:0.7560
# Epoch[2],val_loss:1.6322,val_acc:0.7554
# Epoch[2],val_loss:1.6316,val_acc:0.7555
# Epoch[2],val_loss:1.6310,val_acc:0.7555
# Epoch[2],val_loss:1.6305,val_acc:0.7555
# Epoch[2],val_loss:1.6299,val_acc:0.7556
# Epoch[2],val_loss:1.6293,val_acc:0.7558
# Epoch[2],val_loss:1.6288,val_acc:0.7559
# Epoch[2],val_loss:1.6282,val_acc:0.7563
# Epoch[2],val_loss:1.6277,val_acc:0.7559
# Epoch[2],val_loss:1.6271,val_acc:0.7555
# Epoch[2],val_loss:1.6266,val_acc:0.7555
# Epoch[2],val_loss:1.6261,val_acc:0.7558
# Epoch[2],val_loss:1.6255,val_acc:0.7560
# Epoch[2],val_loss:1.6250,val_acc:0.7555
# Epoch[2],val_loss:1.6244,val_acc:0.7557
# Epoch[2],val_loss:1.6239,val_acc:0.7558
# Epoch[2],val_loss:1.6234,val_acc:0.7558
# Epoch[2],val_loss:1.6228,val_acc:0.7560
# Epoch[2],val_loss:1.6222,val_acc:0.7557
# Epoch[2],val_loss:1.6217,val_acc:0.7562
# Epoch[2],val_loss:1.6211,val_acc:0.7566
# Epoch[2],val_loss:1.6206,val_acc:0.7568
# Epoch[2],val_loss:1.6200,val_acc:0.7568
# Epoch[2],val_loss:1.6195,val_acc:0.7568
# Epoch[2],val_loss:1.6189,val_acc:0.7573
# Epoch[2],val_loss:1.6184,val_acc:0.7580
# Epoch[2],val_loss:1.6179,val_acc:0.7580
# Epoch[2],val_loss:1.6173,val_acc:0.7584
# Epoch[2],val_loss:1.6168,val_acc:0.7582
# Epoch[2],val_loss:1.6163,val_acc:0.7585
# Epoch[2],val_loss:1.6157,val_acc:0.7584
# Epoch[2],val_loss:1.6151,val_acc:0.7586
# Epoch[2],val_loss:1.6146,val_acc:0.7589
# Epoch[2],val_loss:1.6140,val_acc:0.7584
# Epoch[2],val_loss:1.6134,val_acc:0.7589
# Epoch[2],val_loss:1.6129,val_acc:0.7590
# Epoch[2],val_loss:1.6123,val_acc:0.7588
# Epoch[2],val_loss:1.6117,val_acc:0.7586
# Epoch[2],val_loss:1.6112,val_acc:0.7580
# Epoch[2],val_loss:1.6106,val_acc:0.7580
# Epoch[2],val_loss:1.6100,val_acc:0.7584
# Epoch[2],val_loss:1.6095,val_acc:0.7584
# Epoch[2],val_loss:1.6090,val_acc:0.7579
# Epoch[2],val_loss:1.6084,val_acc:0.7581
# Epoch[2],val_loss:1.6079,val_acc:0.7579
# Epoch[2],val_loss:1.6074,val_acc:0.7578
# Epoch[2],val_loss:1.6068,val_acc:0.7585
# Epoch[2],val_loss:1.6063,val_acc:0.7586
# Epoch[2],val_loss:1.6057,val_acc:0.7591
# Epoch[2],val_loss:1.6052,val_acc:0.7590
# Epoch[2],val_loss:1.6046,val_acc:0.7590
# Epoch[2],val_loss:1.6041,val_acc:0.7591
# Epoch[2],val_loss:1.6035,val_acc:0.7591
# Epoch[2],val_loss:1.6030,val_acc:0.7593
# Epoch[2],val_loss:1.6024,val_acc:0.7593
# Epoch[2],val_loss:1.6019,val_acc:0.7597
# Epoch[2],val_loss:1.6014,val_acc:0.7589
# Epoch[2],val_loss:1.6009,val_acc:0.7591
# Epoch[2],val_loss:1.6004,val_acc:0.7593
# Epoch[2],val_loss:1.5999,val_acc:0.7593
# Epoch[2],val_loss:1.5993,val_acc:0.7588
# Epoch[2],val_loss:1.5988,val_acc:0.7596
# Epoch[2],val_loss:1.5982,val_acc:0.7591
# Epoch[2],val_loss:1.5977,val_acc:0.7590
# Epoch[2],val_loss:1.5972,val_acc:0.7593
# Epoch[2],val_loss:1.5966,val_acc:0.7596
# Epoch[2],val_loss:1.5961,val_acc:0.7601
# Epoch[2],val_loss:1.5956,val_acc:0.7601
# Epoch[2],val_loss:1.5951,val_acc:0.7601
# Epoch[2],val_loss:1.5946,val_acc:0.7605
# Epoch[2],val_loss:1.5940,val_acc:0.7607
# Epoch[2],val_loss:1.5935,val_acc:0.7616
# Epoch[2],val_loss:1.5930,val_acc:0.7616
# Epoch[2],val_loss:1.5924,val_acc:0.7617
# Epoch[2],val_loss:1.5919,val_acc:0.7623
# Epoch[2],val_loss:1.5913,val_acc:0.7621
# Epoch[2],val_loss:1.5909,val_acc:0.7623
# Epoch[2],val_loss:1.5903,val_acc:0.7621
# Epoch[2],val_loss:1.5898,val_acc:0.7628
# Epoch[2],val_loss:1.5892,val_acc:0.7624
# Epoch[2],val_loss:1.5887,val_acc:0.7622
# Epoch[2],val_loss:1.5882,val_acc:0.7627
# Epoch[2],val_loss:1.5877,val_acc:0.7622
# Epoch[2],val_loss:1.5871,val_acc:0.7626
# Epoch[2],val_loss:1.5866,val_acc:0.7623
# Epoch[2],val_loss:1.5861,val_acc:0.7623
# Epoch[2],val_loss:1.5856,val_acc:0.7628
# Epoch[2],val_loss:1.5850,val_acc:0.7629
# Epoch[2],val_loss:1.5846,val_acc:0.7629
# Epoch[2],val_loss:1.5840,val_acc:0.7629
# Epoch[2],val_loss:1.5835,val_acc:0.7628
# Epoch[2],val_loss:1.5830,val_acc:0.7629
# Epoch[2],val_loss:1.5825,val_acc:0.7625
# Epoch[2],val_loss:1.5820,val_acc:0.7624
# Epoch[2],val_loss:1.5815,val_acc:0.7624
# Epoch[2],val_loss:1.5810,val_acc:0.7622
# Epoch[2],val_loss:1.5805,val_acc:0.7628
# Epoch[2],val_loss:1.5800,val_acc:0.7627
# Epoch[2],val_loss:1.5796,val_acc:0.7634
# Epoch[2],val_loss:1.5791,val_acc:0.7635
# Epoch[2],val_loss:1.5785,val_acc:0.7636
# Epoch[2],val_loss:1.5780,val_acc:0.7636
# Epoch[2],val_loss:1.5775,val_acc:0.7638
# Epoch[2],val_loss:1.5770,val_acc:0.7639
# Epoch[2],val_loss:1.5765,val_acc:0.7641
# Epoch[2],val_loss:1.5760,val_acc:0.7642
# Epoch[2],val_loss:1.5754,val_acc:0.7644
# Epoch[2],val_loss:1.5749,val_acc:0.7639
# Epoch[2],val_loss:1.5743,val_acc:0.7637
# Epoch[2],val_loss:1.5739,val_acc:0.7638
# Epoch[2],val_loss:1.5733,val_acc:0.7636
# Epoch[2],val_loss:1.5728,val_acc:0.7638
# Epoch[2],val_loss:1.5723,val_acc:0.7638
# Epoch[2],val_loss:1.5718,val_acc:0.7643
# Epoch[2],val_loss:1.5713,val_acc:0.7637
# Epoch[2],val_loss:1.5707,val_acc:0.7641
# Epoch[2],val_loss:1.5702,val_acc:0.7634
# Epoch[2],val_loss:1.5697,val_acc:0.7642
# Epoch[2],val_loss:1.5692,val_acc:0.7634
# Epoch[2],val_loss:1.5687,val_acc:0.7636
# Epoch[2],val_loss:1.5681,val_acc:0.7637
# Epoch[2],val_loss:1.5676,val_acc:0.7650
# Epoch[2],val_loss:1.5671,val_acc:0.7642
# Epoch[2],val_loss:1.5666,val_acc:0.7640
# Epoch[2],val_loss:1.5661,val_acc:0.7640
# Epoch[2],val_loss:1.5655,val_acc:0.7640
# Epoch[2],val_loss:1.5650,val_acc:0.7643
# Epoch[2],val_loss:1.5645,val_acc:0.7648
# Epoch[2],val_loss:1.5640,val_acc:0.7646
# Epoch[2],val_loss:1.5635,val_acc:0.7651
# Epoch[2],val_loss:1.5630,val_acc:0.7645
# Epoch[2],val_loss:1.5625,val_acc:0.7644
# Epoch[2],val_loss:1.5620,val_acc:0.7640
# Epoch[2],val_loss:1.5615,val_acc:0.7644
# Epoch[2],val_loss:1.5610,val_acc:0.7652
# Epoch[2],val_loss:1.5605,val_acc:0.7642
# Epoch[2],val_loss:1.5600,val_acc:0.7650
# Epoch[2],val_loss:1.5594,val_acc:0.7663
# Epoch[2],val_loss:1.5590,val_acc:0.7652
# Epoch[2],val_loss:1.5585,val_acc:0.7659
# Epoch[2],val_loss:1.5581,val_acc:0.7660
# Epoch[2],val_loss:1.5575,val_acc:0.7654
# Epoch[2],val_loss:1.5571,val_acc:0.7659
# Epoch[2],val_loss:1.5566,val_acc:0.7655
# Epoch[2],val_loss:1.5561,val_acc:0.7655
# Epoch[2],val_loss:1.5556,val_acc:0.7653
# Epoch[2],val_loss:1.5550,val_acc:0.7654
# Epoch[2],val_loss:1.5546,val_acc:0.7652
# Epoch[2],val_loss:1.5541,val_acc:0.7652
# Epoch[2],val_loss:1.5536,val_acc:0.7654
# Epoch[2],val_loss:1.5532,val_acc:0.7651
# Epoch[2],val_loss:1.5526,val_acc:0.7653
# Epoch[2],val_loss:1.5521,val_acc:0.7659
# Epoch[2],val_loss:1.5517,val_acc:0.7665
# Epoch[2],val_loss:1.5512,val_acc:0.7663
# Epoch[2],val_loss:1.5507,val_acc:0.7659
# Epoch[2],val_loss:1.5502,val_acc:0.7665
# Epoch[2],val_loss:1.5497,val_acc:0.7668
# Epoch[2],val_loss:1.5491,val_acc:0.7668
# Epoch[2],val_loss:1.5486,val_acc:0.7666
# Epoch[2],val_loss:1.5482,val_acc:0.7670
# Epoch[2],val_loss:1.5477,val_acc:0.7671
# Epoch[2],val_loss:1.5472,val_acc:0.7669
# Epoch[2],val_loss:1.5467,val_acc:0.7667
# Epoch[2],val_loss:1.5462,val_acc:0.7668
# Epoch[2],val_loss:1.5457,val_acc:0.7669
# Epoch[2],val_loss:1.5452,val_acc:0.7667
# Epoch[2],val_loss:1.5446,val_acc:0.7671
# Epoch[2],val_loss:1.5441,val_acc:0.7674
# Epoch[2],val_loss:1.5436,val_acc:0.7672
# Epoch[2],val_loss:1.5431,val_acc:0.7675
# Epoch[2],val_loss:1.5427,val_acc:0.7676
# Epoch[2],val_loss:1.5422,val_acc:0.7676
# Epoch[2],val_loss:1.5417,val_acc:0.7677
# Epoch[2],val_loss:1.5412,val_acc:0.7678
# Epoch[2],val_loss:1.5407,val_acc:0.7675
# Epoch[2],val_loss:1.5402,val_acc:0.7675
# Epoch[2],val_loss:1.5397,val_acc:0.7679
# Epoch[2],val_loss:1.5393,val_acc:0.7678
# Epoch[2],val_loss:1.5388,val_acc:0.7681
# Epoch[2],val_loss:1.5384,val_acc:0.7682
# Epoch[2],val_loss:1.5378,val_acc:0.7681
# Epoch[2],val_loss:1.5374,val_acc:0.7678
# Epoch[2],val_loss:1.5368,val_acc:0.7684
# Epoch[2],val_loss:1.5363,val_acc:0.7685
# Epoch[2],val_loss:1.5359,val_acc:0.7691
# Epoch[2],val_loss:1.5354,val_acc:0.7690
# Epoch[2],val_loss:1.5349,val_acc:0.7689
# Epoch[2],val_loss:1.5345,val_acc:0.7687
# Epoch[2],val_loss:1.5339,val_acc:0.7686
# Epoch[2],val_loss:1.5335,val_acc:0.7689
# Epoch[2],val_loss:1.5330,val_acc:0.7690
# Epoch[2],val_loss:1.5325,val_acc:0.7692
# Epoch[2],val_loss:1.5321,val_acc:0.7693
# Epoch[2],val_loss:1.5316,val_acc:0.7693
# Epoch[2],val_loss:1.5312,val_acc:0.7696
# Epoch[2],val_loss:1.5307,val_acc:0.7696
# Epoch[2],val_loss:1.5302,val_acc:0.7695
# Epoch[2],val_loss:1.5297,val_acc:0.7698
# Epoch[2],val_loss:1.5293,val_acc:0.7696
# Epoch[2],val_loss:1.5288,val_acc:0.7703
# Epoch[2],val_loss:1.5283,val_acc:0.7699
# Epoch[2],val_loss:1.5278,val_acc:0.7700
# Epoch[2],val_loss:1.5274,val_acc:0.7704
# Epoch[2],val_loss:1.5269,val_acc:0.7708
# Epoch[2],val_loss:1.5264,val_acc:0.7707
# Epoch[2],val_loss:1.5259,val_acc:0.7707
# Epoch[2],val_loss:1.5254,val_acc:0.7708
# Epoch[2],val_loss:1.5249,val_acc:0.7705
# Epoch[2],val_loss:1.5244,val_acc:0.7705
# Epoch[2],val_loss:1.5240,val_acc:0.7701
# Epoch[2],val_loss:1.5235,val_acc:0.7707
# Epoch[2],val_loss:1.5230,val_acc:0.7709
# Epoch[2],val_loss:1.5225,val_acc:0.7707
# Epoch[2],val_loss:1.5221,val_acc:0.7708
# Epoch[2],val_loss:1.5216,val_acc:0.7711
# Epoch[2],val_loss:1.5211,val_acc:0.7712
# Epoch[2],val_loss:1.5206,val_acc:0.7718
# Epoch[2],val_loss:1.5201,val_acc:0.7715
# Epoch[2],val_loss:1.5196,val_acc:0.7719
# Epoch[2],val_loss:1.5191,val_acc:0.7717
# Epoch[2],val_loss:1.5186,val_acc:0.7719
# Epoch[2],val_loss:1.5182,val_acc:0.7724
# Epoch[2],val_loss:1.5177,val_acc:0.7723
# Epoch[2],val_loss:1.5172,val_acc:0.7723
# Epoch[2],val_loss:1.5167,val_acc:0.7723
# Epoch[2],val_loss:1.5162,val_acc:0.7724
# Epoch[2],val_loss:1.5158,val_acc:0.7723
# Epoch[2],val_loss:1.5153,val_acc:0.7723
# Epoch[2],val_loss:1.5148,val_acc:0.7722
# Epoch[2],val_loss:1.5143,val_acc:0.7724
# Epoch[2],val_loss:1.5138,val_acc:0.7722
# Epoch[2],val_loss:1.5134,val_acc:0.7723
# Epoch[2],val_loss:1.5129,val_acc:0.7725
# Epoch[2],val_loss:1.5124,val_acc:0.7724
# Epoch[2],val_loss:1.5119,val_acc:0.7725
# Epoch[2],val_loss:1.5115,val_acc:0.7727
# Epoch[2],val_loss:1.5110,val_acc:0.7726
# Epoch[2],val_loss:1.5105,val_acc:0.7722
# Epoch[2],val_loss:1.5101,val_acc:0.7725
# Epoch[2],val_loss:1.5097,val_acc:0.7724
# Epoch[2],val_loss:1.5093,val_acc:0.7720
# Epoch[2],val_loss:1.5088,val_acc:0.7724
# Epoch[2],val_loss:1.5083,val_acc:0.7722
# Epoch[2],val_loss:1.5078,val_acc:0.7723
# Epoch[2],val_loss:1.5073,val_acc:0.7722
# Epoch[2],val_loss:1.5069,val_acc:0.7724
# Epoch[2],val_loss:1.5064,val_acc:0.7725
# Epoch[2],val_loss:1.5060,val_acc:0.7730
# Epoch[2],val_loss:1.5055,val_acc:0.7734
# Epoch[2],val_loss:1.5050,val_acc:0.7738
# Epoch[2],val_loss:1.5045,val_acc:0.7736
# Epoch[2],val_loss:1.5041,val_acc:0.7739
# Epoch[2],val_loss:1.5036,val_acc:0.7742
# Epoch[2],val_loss:1.5031,val_acc:0.7743
# Epoch[2],val_loss:1.5026,val_acc:0.7742
# Epoch[2],val_loss:1.5021,val_acc:0.7746
# Epoch[2],val_loss:1.5016,val_acc:0.7747
# Epoch[2],val_loss:1.5012,val_acc:0.7749
# Epoch[2],val_loss:1.5007,val_acc:0.7748
# Epoch[2],val_loss:1.5003,val_acc:0.7754
# Epoch[2],val_loss:1.4998,val_acc:0.7749
# Epoch[2],val_loss:1.4993,val_acc:0.7747
# Epoch[2],val_loss:1.4989,val_acc:0.7747
# Epoch[2],val_loss:1.4984,val_acc:0.7751
# Epoch[2],val_loss:1.4980,val_acc:0.7759
# Epoch[2],val_loss:1.4975,val_acc:0.7759
# Epoch[2],val_loss:1.4970,val_acc:0.7756
# Epoch[2],val_loss:1.4966,val_acc:0.7756
# Epoch[2],val_loss:1.4961,val_acc:0.7751
# Epoch[2],val_loss:1.4957,val_acc:0.7753
# Epoch[2],val_loss:1.4952,val_acc:0.7750
# Epoch[2],val_loss:1.4947,val_acc:0.7750
# Epoch[2],val_loss:1.4943,val_acc:0.7752
# Epoch[2],val_loss:1.4938,val_acc:0.7755
# Epoch[2],val_loss:1.4933,val_acc:0.7756
# Epoch[2],val_loss:1.4929,val_acc:0.7755
# Epoch[2],val_loss:1.4924,val_acc:0.7765
# Epoch[2],val_loss:1.4920,val_acc:0.7762
# Epoch[2],val_loss:1.4915,val_acc:0.7760
# Epoch[2],val_loss:1.4910,val_acc:0.7759
# Epoch[2],val_loss:1.4905,val_acc:0.7763
# Epoch[2],val_loss:1.4901,val_acc:0.7762
# Epoch[2],val_loss:1.4896,val_acc:0.7756
# Epoch[2],val_loss:1.4892,val_acc:0.7753
# Epoch[2],val_loss:1.4887,val_acc:0.7756
# Epoch[2],val_loss:1.4883,val_acc:0.7756
# Epoch[2],val_loss:1.4878,val_acc:0.7757
# Epoch[2],val_loss:1.4874,val_acc:0.7757
# Epoch[2],val_loss:1.4869,val_acc:0.7757
# Epoch[2],val_loss:1.4864,val_acc:0.7759
# Epoch[2],val_loss:1.4860,val_acc:0.7760
# Epoch[2],val_loss:1.4856,val_acc:0.7766
# Epoch[2],val_loss:1.4851,val_acc:0.7768
# Epoch[2],val_loss:1.4847,val_acc:0.7771
# Epoch[2],val_loss:1.4842,val_acc:0.7767
# Epoch[2],val_loss:1.4838,val_acc:0.7767
# Epoch[2],val_loss:1.4834,val_acc:0.7767
# Epoch[2],val_loss:1.4829,val_acc:0.7764
# Epoch[2],val_loss:1.4825,val_acc:0.7769
# Epoch[2],val_loss:1.4820,val_acc:0.7767
# Epoch[2],val_loss:1.4816,val_acc:0.7769
# Epoch[2],val_loss:1.4811,val_acc:0.7769
# Epoch[2],val_loss:1.4807,val_acc:0.7772
# Epoch[2],val_loss:1.4802,val_acc:0.7774
# Epoch[2],val_loss:1.4798,val_acc:0.7771
# Epoch[2],val_loss:1.4793,val_acc:0.7770
# Epoch[3],val_loss:1.4789,val_acc:0.7771
# Epoch[3],val_loss:1.4784,val_acc:0.7773
# Epoch[3],val_loss:1.4780,val_acc:0.7771
# Epoch[3],val_loss:1.4776,val_acc:0.7773
# Epoch[3],val_loss:1.4771,val_acc:0.7772
# Epoch[3],val_loss:1.4767,val_acc:0.7773
# Epoch[3],val_loss:1.4762,val_acc:0.7775
# Epoch[3],val_loss:1.4758,val_acc:0.7775
# Epoch[3],val_loss:1.4754,val_acc:0.7776
# Epoch[3],val_loss:1.4750,val_acc:0.7773
# Epoch[3],val_loss:1.4745,val_acc:0.7774
# Epoch[3],val_loss:1.4741,val_acc:0.7775
# Epoch[3],val_loss:1.4737,val_acc:0.7776
# Epoch[3],val_loss:1.4732,val_acc:0.7776
# Epoch[3],val_loss:1.4728,val_acc:0.7780
# Epoch[3],val_loss:1.4724,val_acc:0.7775
# Epoch[3],val_loss:1.4719,val_acc:0.7776
# Epoch[3],val_loss:1.4715,val_acc:0.7780
# Epoch[3],val_loss:1.4711,val_acc:0.7777
# Epoch[3],val_loss:1.4707,val_acc:0.7777
# Epoch[3],val_loss:1.4702,val_acc:0.7776
# Epoch[3],val_loss:1.4698,val_acc:0.7774
# Epoch[3],val_loss:1.4693,val_acc:0.7778
# Epoch[3],val_loss:1.4689,val_acc:0.7777
# Epoch[3],val_loss:1.4685,val_acc:0.7781
# Epoch[3],val_loss:1.4680,val_acc:0.7781
# Epoch[3],val_loss:1.4676,val_acc:0.7778
# Epoch[3],val_loss:1.4672,val_acc:0.7776
# Epoch[3],val_loss:1.4667,val_acc:0.7776
# Epoch[3],val_loss:1.4663,val_acc:0.7779
# Epoch[3],val_loss:1.4659,val_acc:0.7780
# Epoch[3],val_loss:1.4655,val_acc:0.7778
# Epoch[3],val_loss:1.4650,val_acc:0.7785
# Epoch[3],val_loss:1.4646,val_acc:0.7785
# Epoch[3],val_loss:1.4641,val_acc:0.7783
# Epoch[3],val_loss:1.4637,val_acc:0.7785
# Epoch[3],val_loss:1.4633,val_acc:0.7783
# Epoch[3],val_loss:1.4628,val_acc:0.7783
# Epoch[3],val_loss:1.4624,val_acc:0.7783
# Epoch[3],val_loss:1.4620,val_acc:0.7785
# Epoch[3],val_loss:1.4615,val_acc:0.7784
# Epoch[3],val_loss:1.4611,val_acc:0.7786
# Epoch[3],val_loss:1.4606,val_acc:0.7784
# Epoch[3],val_loss:1.4602,val_acc:0.7785
# Epoch[3],val_loss:1.4597,val_acc:0.7781
# Epoch[3],val_loss:1.4593,val_acc:0.7780
# Epoch[3],val_loss:1.4589,val_acc:0.7782
# Epoch[3],val_loss:1.4584,val_acc:0.7784
# Epoch[3],val_loss:1.4580,val_acc:0.7784
# Epoch[3],val_loss:1.4576,val_acc:0.7784
# Epoch[3],val_loss:1.4572,val_acc:0.7783
# Epoch[3],val_loss:1.4567,val_acc:0.7783
# Epoch[3],val_loss:1.4563,val_acc:0.7782
# Epoch[3],val_loss:1.4559,val_acc:0.7786
# Epoch[3],val_loss:1.4555,val_acc:0.7792
# Epoch[3],val_loss:1.4550,val_acc:0.7786
# Epoch[3],val_loss:1.4546,val_acc:0.7785
# Epoch[3],val_loss:1.4542,val_acc:0.7789
# Epoch[3],val_loss:1.4538,val_acc:0.7788
# Epoch[3],val_loss:1.4534,val_acc:0.7788
# Epoch[3],val_loss:1.4529,val_acc:0.7788
# Epoch[3],val_loss:1.4524,val_acc:0.7788
# Epoch[3],val_loss:1.4520,val_acc:0.7788
# Epoch[3],val_loss:1.4516,val_acc:0.7790
# Epoch[3],val_loss:1.4512,val_acc:0.7788
# Epoch[3],val_loss:1.4508,val_acc:0.7792
# Epoch[3],val_loss:1.4503,val_acc:0.7790
# Epoch[3],val_loss:1.4499,val_acc:0.7789
# Epoch[3],val_loss:1.4495,val_acc:0.7793
# Epoch[3],val_loss:1.4491,val_acc:0.7791
# Epoch[3],val_loss:1.4487,val_acc:0.7791
# Epoch[3],val_loss:1.4483,val_acc:0.7792
# Epoch[3],val_loss:1.4478,val_acc:0.7792
# Epoch[3],val_loss:1.4474,val_acc:0.7794
# Epoch[3],val_loss:1.4470,val_acc:0.7790
# Epoch[3],val_loss:1.4466,val_acc:0.7789
# Epoch[3],val_loss:1.4462,val_acc:0.7795
# Epoch[3],val_loss:1.4457,val_acc:0.7795
# Epoch[3],val_loss:1.4453,val_acc:0.7800
# Epoch[3],val_loss:1.4449,val_acc:0.7793
# Epoch[3],val_loss:1.4445,val_acc:0.7792
# Epoch[3],val_loss:1.4441,val_acc:0.7794
# Epoch[3],val_loss:1.4436,val_acc:0.7797
# Epoch[3],val_loss:1.4432,val_acc:0.7800
# Epoch[3],val_loss:1.4428,val_acc:0.7799
# Epoch[3],val_loss:1.4424,val_acc:0.7798
# Epoch[3],val_loss:1.4420,val_acc:0.7802
# Epoch[3],val_loss:1.4416,val_acc:0.7801
# Epoch[3],val_loss:1.4412,val_acc:0.7804
# Epoch[3],val_loss:1.4408,val_acc:0.7804
# Epoch[3],val_loss:1.4403,val_acc:0.7804
# Epoch[3],val_loss:1.4399,val_acc:0.7805
# Epoch[3],val_loss:1.4395,val_acc:0.7805
# Epoch[3],val_loss:1.4391,val_acc:0.7802
# Epoch[3],val_loss:1.4387,val_acc:0.7800
# Epoch[3],val_loss:1.4383,val_acc:0.7799
# Epoch[3],val_loss:1.4379,val_acc:0.7796
# Epoch[3],val_loss:1.4375,val_acc:0.7796
# Epoch[3],val_loss:1.4371,val_acc:0.7796
# Epoch[3],val_loss:1.4366,val_acc:0.7799
# Epoch[3],val_loss:1.4362,val_acc:0.7796
# Epoch[3],val_loss:1.4358,val_acc:0.7800
# Epoch[3],val_loss:1.4354,val_acc:0.7798
# Epoch[3],val_loss:1.4350,val_acc:0.7799
# Epoch[3],val_loss:1.4346,val_acc:0.7800
# Epoch[3],val_loss:1.4342,val_acc:0.7803
# Epoch[3],val_loss:1.4338,val_acc:0.7803
# Epoch[3],val_loss:1.4333,val_acc:0.7803
# Epoch[3],val_loss:1.4330,val_acc:0.7804
# Epoch[3],val_loss:1.4326,val_acc:0.7807
# Epoch[3],val_loss:1.4322,val_acc:0.7803
# Epoch[3],val_loss:1.4318,val_acc:0.7808
# Epoch[3],val_loss:1.4314,val_acc:0.7812
# Epoch[3],val_loss:1.4309,val_acc:0.7814
# Epoch[3],val_loss:1.4306,val_acc:0.7813
# Epoch[3],val_loss:1.4301,val_acc:0.7812
# Epoch[3],val_loss:1.4297,val_acc:0.7813
# Epoch[3],val_loss:1.4293,val_acc:0.7811
# Epoch[3],val_loss:1.4289,val_acc:0.7810
# Epoch[3],val_loss:1.4284,val_acc:0.7807
# Epoch[3],val_loss:1.4280,val_acc:0.7808
# Epoch[3],val_loss:1.4276,val_acc:0.7808
# Epoch[3],val_loss:1.4272,val_acc:0.7807
# Epoch[3],val_loss:1.4268,val_acc:0.7810
# Epoch[3],val_loss:1.4264,val_acc:0.7806
# Epoch[3],val_loss:1.4260,val_acc:0.7810
# Epoch[3],val_loss:1.4255,val_acc:0.7810
# Epoch[3],val_loss:1.4251,val_acc:0.7809
# Epoch[3],val_loss:1.4247,val_acc:0.7807
# Epoch[3],val_loss:1.4243,val_acc:0.7807
# Epoch[3],val_loss:1.4239,val_acc:0.7807
# Epoch[3],val_loss:1.4236,val_acc:0.7809
# Epoch[3],val_loss:1.4231,val_acc:0.7809
# Epoch[3],val_loss:1.4227,val_acc:0.7808
# Epoch[3],val_loss:1.4223,val_acc:0.7807
# Epoch[3],val_loss:1.4219,val_acc:0.7813
# Epoch[3],val_loss:1.4215,val_acc:0.7810
# Epoch[3],val_loss:1.4211,val_acc:0.7813
# Epoch[3],val_loss:1.4207,val_acc:0.7814
# Epoch[3],val_loss:1.4203,val_acc:0.7812
# Epoch[3],val_loss:1.4198,val_acc:0.7816
# Epoch[3],val_loss:1.4194,val_acc:0.7814
# Epoch[3],val_loss:1.4191,val_acc:0.7810
# Epoch[3],val_loss:1.4187,val_acc:0.7815
# Epoch[3],val_loss:1.4183,val_acc:0.7811
# Epoch[3],val_loss:1.4179,val_acc:0.7812
# Epoch[3],val_loss:1.4176,val_acc:0.7815
# Epoch[3],val_loss:1.4172,val_acc:0.7815
# Epoch[3],val_loss:1.4167,val_acc:0.7815
# Epoch[3],val_loss:1.4163,val_acc:0.7814
# Epoch[3],val_loss:1.4159,val_acc:0.7814
# Epoch[3],val_loss:1.4155,val_acc:0.7819
# Epoch[3],val_loss:1.4151,val_acc:0.7821
# Epoch[3],val_loss:1.4147,val_acc:0.7822
# Epoch[3],val_loss:1.4143,val_acc:0.7828
# Epoch[3],val_loss:1.4139,val_acc:0.7829
# Epoch[3],val_loss:1.4135,val_acc:0.7830
# Epoch[3],val_loss:1.4131,val_acc:0.7831
# Epoch[3],val_loss:1.4127,val_acc:0.7834
# Epoch[3],val_loss:1.4123,val_acc:0.7836
# Epoch[3],val_loss:1.4119,val_acc:0.7834
# Epoch[3],val_loss:1.4115,val_acc:0.7836
# Epoch[3],val_loss:1.4111,val_acc:0.7831
# Epoch[3],val_loss:1.4107,val_acc:0.7833
# Epoch[3],val_loss:1.4103,val_acc:0.7829
# Epoch[3],val_loss:1.4100,val_acc:0.7834
# Epoch[3],val_loss:1.4096,val_acc:0.7834
# Epoch[3],val_loss:1.4091,val_acc:0.7838
# Epoch[3],val_loss:1.4087,val_acc:0.7836
# Epoch[3],val_loss:1.4083,val_acc:0.7834
# Epoch[3],val_loss:1.4079,val_acc:0.7836
# Epoch[3],val_loss:1.4075,val_acc:0.7836
# Epoch[3],val_loss:1.4071,val_acc:0.7837
# Epoch[3],val_loss:1.4067,val_acc:0.7837
# Epoch[3],val_loss:1.4064,val_acc:0.7838
# Epoch[3],val_loss:1.4060,val_acc:0.7839
# Epoch[3],val_loss:1.4056,val_acc:0.7840
# Epoch[3],val_loss:1.4051,val_acc:0.7839
# Epoch[3],val_loss:1.4048,val_acc:0.7841
# Epoch[3],val_loss:1.4044,val_acc:0.7839
# Epoch[3],val_loss:1.4040,val_acc:0.7841
# Epoch[3],val_loss:1.4036,val_acc:0.7842
# Epoch[3],val_loss:1.4032,val_acc:0.7839
# Epoch[3],val_loss:1.4028,val_acc:0.7841
# Epoch[3],val_loss:1.4025,val_acc:0.7841
# Epoch[3],val_loss:1.4021,val_acc:0.7839
# Epoch[3],val_loss:1.4017,val_acc:0.7840
# Epoch[3],val_loss:1.4013,val_acc:0.7845
# Epoch[3],val_loss:1.4009,val_acc:0.7845
# Epoch[3],val_loss:1.4005,val_acc:0.7847
# Epoch[3],val_loss:1.4002,val_acc:0.7842
# Epoch[3],val_loss:1.3998,val_acc:0.7846
# Epoch[3],val_loss:1.3994,val_acc:0.7842
# Epoch[3],val_loss:1.3990,val_acc:0.7844
# Epoch[3],val_loss:1.3986,val_acc:0.7841
# Epoch[3],val_loss:1.3983,val_acc:0.7844
# Epoch[3],val_loss:1.3979,val_acc:0.7844
# Epoch[3],val_loss:1.3975,val_acc:0.7844
# Epoch[3],val_loss:1.3971,val_acc:0.7846
# Epoch[3],val_loss:1.3967,val_acc:0.7844
# Epoch[3],val_loss:1.3963,val_acc:0.7843
# Epoch[3],val_loss:1.3959,val_acc:0.7844
# Epoch[3],val_loss:1.3956,val_acc:0.7841
# Epoch[3],val_loss:1.3952,val_acc:0.7846
# Epoch[3],val_loss:1.3948,val_acc:0.7847
# Epoch[3],val_loss:1.3944,val_acc:0.7850
# Epoch[3],val_loss:1.3940,val_acc:0.7850
# Epoch[3],val_loss:1.3936,val_acc:0.7851
# Epoch[3],val_loss:1.3932,val_acc:0.7849
# Epoch[3],val_loss:1.3928,val_acc:0.7851
# Epoch[3],val_loss:1.3924,val_acc:0.7851
# Epoch[3],val_loss:1.3920,val_acc:0.7851
# Epoch[3],val_loss:1.3916,val_acc:0.7848
# Epoch[3],val_loss:1.3912,val_acc:0.7851
# Epoch[3],val_loss:1.3908,val_acc:0.7849
# Epoch[3],val_loss:1.3904,val_acc:0.7851
# Epoch[3],val_loss:1.3901,val_acc:0.7849
# Epoch[3],val_loss:1.3897,val_acc:0.7849
# Epoch[3],val_loss:1.3893,val_acc:0.7853
# Epoch[3],val_loss:1.3889,val_acc:0.7852
# Epoch[3],val_loss:1.3886,val_acc:0.7851
# Epoch[3],val_loss:1.3882,val_acc:0.7853
# Epoch[3],val_loss:1.3878,val_acc:0.7852
# Epoch[3],val_loss:1.3874,val_acc:0.7853
# Epoch[3],val_loss:1.3870,val_acc:0.7854
# Epoch[3],val_loss:1.3866,val_acc:0.7853
# Epoch[3],val_loss:1.3862,val_acc:0.7854
# Epoch[3],val_loss:1.3858,val_acc:0.7852
# Epoch[3],val_loss:1.3855,val_acc:0.7857
# Epoch[3],val_loss:1.3851,val_acc:0.7857
# Epoch[3],val_loss:1.3848,val_acc:0.7853
# Epoch[3],val_loss:1.3844,val_acc:0.7856
# Epoch[3],val_loss:1.3840,val_acc:0.7855
# Epoch[3],val_loss:1.3836,val_acc:0.7857
# Epoch[3],val_loss:1.3832,val_acc:0.7854
# Epoch[3],val_loss:1.3828,val_acc:0.7855
# Epoch[3],val_loss:1.3824,val_acc:0.7854
# Epoch[3],val_loss:1.3821,val_acc:0.7854
# Epoch[3],val_loss:1.3817,val_acc:0.7854
# Epoch[3],val_loss:1.3813,val_acc:0.7858
# Epoch[3],val_loss:1.3810,val_acc:0.7855
# Epoch[3],val_loss:1.3806,val_acc:0.7862
# Epoch[3],val_loss:1.3803,val_acc:0.7863
# Epoch[3],val_loss:1.3799,val_acc:0.7865
# Epoch[3],val_loss:1.3795,val_acc:0.7862
# Epoch[3],val_loss:1.3791,val_acc:0.7860
# Epoch[3],val_loss:1.3788,val_acc:0.7860
# Epoch[3],val_loss:1.3784,val_acc:0.7860
# Epoch[3],val_loss:1.3780,val_acc:0.7861
# Epoch[3],val_loss:1.3777,val_acc:0.7863
# Epoch[3],val_loss:1.3773,val_acc:0.7862
# Epoch[3],val_loss:1.3769,val_acc:0.7864
# Epoch[3],val_loss:1.3766,val_acc:0.7866
# Epoch[3],val_loss:1.3762,val_acc:0.7866
# Epoch[3],val_loss:1.3759,val_acc:0.7868
# Epoch[3],val_loss:1.3755,val_acc:0.7869
# Epoch[3],val_loss:1.3752,val_acc:0.7868
# Epoch[3],val_loss:1.3748,val_acc:0.7869
# Epoch[3],val_loss:1.3744,val_acc:0.7875
# Epoch[3],val_loss:1.3740,val_acc:0.7871
# Epoch[3],val_loss:1.3736,val_acc:0.7877
# Epoch[3],val_loss:1.3732,val_acc:0.7877
# Epoch[3],val_loss:1.3729,val_acc:0.7877
# Epoch[3],val_loss:1.3725,val_acc:0.7879
# Epoch[3],val_loss:1.3721,val_acc:0.7884
# Epoch[3],val_loss:1.3718,val_acc:0.7882
# Epoch[3],val_loss:1.3714,val_acc:0.7881
# Epoch[3],val_loss:1.3710,val_acc:0.7881
# Epoch[3],val_loss:1.3706,val_acc:0.7883
# Epoch[3],val_loss:1.3702,val_acc:0.7883
# Epoch[3],val_loss:1.3698,val_acc:0.7883
# Epoch[3],val_loss:1.3695,val_acc:0.7883
# Epoch[3],val_loss:1.3691,val_acc:0.7881
# Epoch[3],val_loss:1.3688,val_acc:0.7881
# Epoch[3],val_loss:1.3684,val_acc:0.7883
# Epoch[3],val_loss:1.3680,val_acc:0.7884
# Epoch[3],val_loss:1.3677,val_acc:0.7884
# Epoch[3],val_loss:1.3673,val_acc:0.7883
# Epoch[3],val_loss:1.3669,val_acc:0.7887
# Epoch[3],val_loss:1.3665,val_acc:0.7889
# Epoch[3],val_loss:1.3662,val_acc:0.7890
# Epoch[3],val_loss:1.3658,val_acc:0.7887
# Epoch[3],val_loss:1.3655,val_acc:0.7887
# Epoch[3],val_loss:1.3651,val_acc:0.7888
# Epoch[3],val_loss:1.3647,val_acc:0.7889
# Epoch[3],val_loss:1.3643,val_acc:0.7891
# Epoch[3],val_loss:1.3640,val_acc:0.7893
# Epoch[3],val_loss:1.3636,val_acc:0.7890
# Epoch[3],val_loss:1.3632,val_acc:0.7889
# Epoch[3],val_loss:1.3629,val_acc:0.7889
# Epoch[3],val_loss:1.3625,val_acc:0.7891
# Epoch[3],val_loss:1.3621,val_acc:0.7892
# Epoch[3],val_loss:1.3618,val_acc:0.7890
# Epoch[3],val_loss:1.3614,val_acc:0.7890
# Epoch[3],val_loss:1.3610,val_acc:0.7893
# Epoch[3],val_loss:1.3606,val_acc:0.7888
# Epoch[3],val_loss:1.3603,val_acc:0.7887
# Epoch[3],val_loss:1.3600,val_acc:0.7889
# Epoch[3],val_loss:1.3596,val_acc:0.7888
# Epoch[3],val_loss:1.3592,val_acc:0.7887
# Epoch[3],val_loss:1.3588,val_acc:0.7889
# Epoch[3],val_loss:1.3585,val_acc:0.7890
# Epoch[3],val_loss:1.3581,val_acc:0.7890
# Epoch[3],val_loss:1.3577,val_acc:0.7888
# Epoch[3],val_loss:1.3574,val_acc:0.7890
# Epoch[3],val_loss:1.3570,val_acc:0.7886
# Epoch[3],val_loss:1.3567,val_acc:0.7886
# Epoch[3],val_loss:1.3563,val_acc:0.7888
# Epoch[3],val_loss:1.3559,val_acc:0.7888
# Epoch[3],val_loss:1.3556,val_acc:0.7889
# Epoch[3],val_loss:1.3552,val_acc:0.7886
# Epoch[3],val_loss:1.3548,val_acc:0.7889
# Epoch[3],val_loss:1.3545,val_acc:0.7890
# Epoch[3],val_loss:1.3541,val_acc:0.7888
# Epoch[3],val_loss:1.3538,val_acc:0.7887
# Epoch[3],val_loss:1.3534,val_acc:0.7888
# Epoch[3],val_loss:1.3531,val_acc:0.7889
# Epoch[3],val_loss:1.3527,val_acc:0.7891
# Epoch[3],val_loss:1.3524,val_acc:0.7893
# Epoch[3],val_loss:1.3520,val_acc:0.7890
# Epoch[3],val_loss:1.3516,val_acc:0.7890
# Epoch[3],val_loss:1.3512,val_acc:0.7892
# Epoch[3],val_loss:1.3509,val_acc:0.7889
# Epoch[3],val_loss:1.3505,val_acc:0.7892
# Epoch[3],val_loss:1.3502,val_acc:0.7891
# Epoch[3],val_loss:1.3498,val_acc:0.7896
# Epoch[3],val_loss:1.3495,val_acc:0.7899
# Epoch[3],val_loss:1.3491,val_acc:0.7894
# Epoch[3],val_loss:1.3487,val_acc:0.7892
# Epoch[3],val_loss:1.3484,val_acc:0.7894
# Epoch[3],val_loss:1.3480,val_acc:0.7891
# Epoch[3],val_loss:1.3477,val_acc:0.7897
# Epoch[3],val_loss:1.3473,val_acc:0.7890
# Epoch[3],val_loss:1.3470,val_acc:0.7895
# Epoch[3],val_loss:1.3466,val_acc:0.7896
# Epoch[3],val_loss:1.3463,val_acc:0.7896
# Epoch[3],val_loss:1.3459,val_acc:0.7895
# Epoch[3],val_loss:1.3456,val_acc:0.7898
# Epoch[3],val_loss:1.3452,val_acc:0.7895
# Epoch[3],val_loss:1.3449,val_acc:0.7896
# Epoch[3],val_loss:1.3445,val_acc:0.7895
# Epoch[3],val_loss:1.3442,val_acc:0.7900
# Epoch[3],val_loss:1.3438,val_acc:0.7900
# Epoch[3],val_loss:1.3435,val_acc:0.7899
# Epoch[3],val_loss:1.3432,val_acc:0.7902
# Epoch[3],val_loss:1.3428,val_acc:0.7899
# Epoch[3],val_loss:1.3425,val_acc:0.7902
# Epoch[3],val_loss:1.3421,val_acc:0.7905
# Epoch[3],val_loss:1.3418,val_acc:0.7905
# Epoch[3],val_loss:1.3414,val_acc:0.7906
# Epoch[3],val_loss:1.3411,val_acc:0.7905

# %%
history=[result0]#+history1+history2+history3+history4
accuracies=[result['val_acc'] for result in history]
plt.plot(accuracy,'-x')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Accuracy vs No. of epochs')

# %% [markdown]
# **Testing with individual images**

# %%
#Defining test dataset
test_dataset=MNIST(root='data/',train=False,transform=transforms.ToTensor())

# %%
img,label=test_dataset[0]
plt.imshow(img[0],cmap='gray')
print("Shape:",img.shape)
print("Label:",label)

# %%
def predict_image(img,model):#Returns predicted image label for a single image tensor
  xb=img.unsqueeze(0)#adds another dimension at the start of 1x28x28 to make it 1x1x28x28 which the model views as a batch containing a single image
  yb=model(xb)
  _,preds=torch.max(yb,dim=1)
  return preds[0].item()

# %%
img,label=test_dataset[0]
plt.imshow(img[0],cmap='gray')
print("Label:",label,',Predicted:',predict_image(img,model))

# %%
img,label=test_dataset[10]
plt.imshow(img[0],cmap='gray')
print('Label:',label,',Predicted:',predict_image(img,model))

# %% [markdown]
# Viewing the overall loss and accuracy of the model on test set

# %%
test_loader=DataLoader(test_dataset,batch_size=256)
result=evaluate(model,test_loader)
result
